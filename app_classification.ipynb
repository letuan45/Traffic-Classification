# %% [markdown]
# DATA PREPROCESSING

# %%
import os
import pandas as pd
import ipaddress
from PIL import Image
import matplotlib.pyplot as plt
from configurations import binary_lable
from utils import has_digit, remove_digits, remove_suffix, classifi_by_rules, decimal_to_256, nearest_square
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from configurations import app_rules
import math
from imblearn.over_sampling import ADASYN
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
# Thư mục chứa các file dataset đã transfer
dataset_folder = "new_transfered_dataset"
# Thư mục chức các file csv đã gán nhãn
classified_folder = "classified_dataset"
files = [f for f in os.listdir(dataset_folder) if f.endswith('.csv')]

# %% [markdown]
# Preprocessing 1. Đọc Dataset, gán nhãn, merge CSV files

# %%
print("##### START READING DATASET ######")
# Danh sách rỗng để lưu trữ các DataFrame
dataframes = []
file_indx = 1
for file in files:
    file_path = os.path.join(dataset_folder, file)
    df = pd.read_csv(file_path)

    # Format tên các cột
    df.columns = df.columns.str.lower().str.replace(' ', '_')

    file_name = file.split(".")[0]

    # Bỏ cột flow_id, timestamp
    df = df.drop('flow_id', axis=1)
    df = df.drop('timestamp', axis=1)

    # Chuyển hóa các địa chỉ IP thành int
    for index, row in df.iterrows():
        int_src_ip = int(ipaddress.ip_address(df.iloc[index]["src_ip"]))
        int_dst_ip = int(ipaddress.ip_address(df.iloc[index]["dst_ip"]))
        df.at[index, 'src_ip'] = int_src_ip
        df.at[index, 'dst_ip'] = int_dst_ip

    # Gán nhãn các row
    processed_name = remove_suffix(file_name)
    label = classifi_by_rules(app_rules, processed_name)
    if(label is not None):
        label_value = label[1]
        df["label"] = label_value
        dataframes.append(df)
    file_indx = file_indx + 1
# Lưu file
merged_df = pd.concat(dataframes, ignore_index=True)
merged_file_path = os.path.join(classified_folder, "app_dataset.csv")
merged_df.to_csv(merged_file_path, index=False)

print("##### READ DATASET DONE ######")
# Out:
# ##### START READING DATASET ######
# ##### READ DATASET DONE ######

# %% [markdown]
# Preprocess 2. Mã hóa cơ số 256, áp dụng MinMaxScaler

# %%
print("##### START ENCODING DATASET ######")

expanded_df = pd.DataFrame()
merged_traffics = pd.read_csv(f'{classified_folder}/app_dataset.csv')
num_of_rows = merged_traffics.shape[0]
for column_name, column_data in merged_traffics.items():
    count = 1
    for index, value in enumerate(column_data):
        result = decimal_to_256(value)
        max_length = len(result)

        # Tạo tên cột mới và giá trị cho từng kết quả
        for i in range(max_length):
            new_column_name = f'{column_name}_{i + 1}'
            if new_column_name not in expanded_df:
                expanded_df[new_column_name] = 0  # Tạo cột mới nếu cần
            expanded_df.at[index, new_column_name] = result[i]
        count += 1
expanded_df.to_csv(merged_file_path, index=False)

# Scaling dữ liệu
traffics = pd.read_csv(f'{classified_folder}/app_dataset.csv')
selected_columns = [col for col in traffics.columns if col.endswith(
    '_1') and not any(f"{col[:-2]}_{i}" in traffics.columns for i in range(2, 10))]
# Loại bỏ label
selected_columns = [item for item in selected_columns if item != "label_1"]
# Khởi tạo Min-Max Scaler
scaler = MinMaxScaler(feature_range=(0, 255))
# Áp dụng Min-Max Scaler
traffics[selected_columns] = scaler.fit_transform(
    traffics[selected_columns])
traffics.to_csv(merged_file_path, index=False)

print("##### ENCODING DONE ######")
# Out:
# ##### START ENCODING DATASET ######
# ##### ENCODING DONE ######

# %% [markdown]
# Preprocess 3. Áp dụng ADASYN resampling

# %%
print("##### DATASET BALANCING WITH ADASYN. ######")

data = pd.read_csv(f'{classified_folder}/app_dataset.csv')
original_class_distribution = data['label_1'].value_counts()

data.fillna(0, inplace=True)
X = data.drop('label_1', axis=1)  # Tập dữ liệu đầu vào
y = data['label_1']  # Nhãn
adasyn = ADASYN(sampling_strategy='not majority', random_state=42,
                n_neighbors=100)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
resampled_data = pd.concat(
    [resampled_data, pd.DataFrame(y_resampled, columns=['label_1'])], axis=1)
resampled_class_distribution = resampled_data['label_1'].value_counts()
balanced_file_path = os.path.join(classified_folder, "app_dataset_balanced.csv")

combined_data = pd.concat([original_class_distribution, resampled_class_distribution], axis=1)
combined_data.columns = ['Original Data', 'Resampled Data']
combined_data = combined_data.sort_index()

class_labels = combined_data.index

label_to_name = {rule['label']: rule['name'] for rule in app_rules}
class_labels_mapped = [label_to_name[label] for label in class_labels]

plt.figure(figsize=(10, 6))
width = 0.4

plt.bar(range(len(class_labels_mapped)), combined_data['Original Data'], width=0.4, label='Original Data')
plt.bar([x + width for x in range(len(class_labels_mapped))], combined_data['Resampled Data'], width=0.4, label='Resampled Data')

plt.xlabel('Name')
plt.ylabel('Number of Samples')
plt.xticks([x + width/2 for x in range(len(class_labels_mapped))], class_labels_mapped, rotation=45)  # Set the x-ticks to be class names
plt.legend()
plt.show()
resampled_data.to_csv(balanced_file_path, index=False)
print("##### RESAMPLING WITH ADASYN DONE ######")
# Out:
# ##### DATASET BALANCING WITH ADASYN. ######
# ##### RESAMPLING WITH ADASYN DONE ######

# %% [markdown]
# Preprocess 4. Fill các dữ liệu còn thiếu bằng 0

# %%
print("##### START ADDING ZEROS TO DATASET ######")

df = pd.read_csv(f'{classified_folder}/app_dataset_balanced.csv')
img_shape = nearest_square(df.shape[1]) + 1
num_new_columns = img_shape - df.shape[1]

for i in range(1, num_new_columns + 1):
    new_col_name = f'zeros_{i}'
    df.insert(df.shape[1] - 1, new_col_name, 0)
df.to_csv(merged_file_path, index=False)
print("Dataset's shape", df.shape)

print("##### ADD ZEROS TO DATASET DONE ######")
# Out:
# ##### START ADDING ZEROS TO DATASET ######
# Dataset's shape (227069, 226)
# ##### ADD ZEROS TO DATASET DONE ######

# %% [markdown]
# Preprocess 5. Chuyển từng dòng dữ liệu thành Image

# %%
print("##### START CREATTING IMAGES ######")

df = pd.read_csv(f'{classified_folder}/app_dataset.csv')
img_shape = nearest_square(df.shape[1]) + 1
data_img_shape = int(math.sqrt(img_shape-1))
for index, row in df.iterrows():
    data_row = df.iloc[index]
    label = data_row['label_1']
    data_row = data_row.drop('label_1')

    data_array = data_row.values.reshape(data_img_shape, data_img_shape)
    # Tạo hình ảnh từ mảng numpy
    image = Image.fromarray((data_array).astype('uint8'))

    output_folder = ""
    row_label = row["label_1"]
    for rule in app_rules:
        if rule["label"] == row_label:
            output_folder = rule["name"]

    output_folder_path = os.path.join(
        f'image_dataset/app_dataset/{output_folder}')
    # Tạo đường dẫn đầy đủ đến thư mục đích -> lưu
    output_path = os.path.join(
        f'image_dataset/app_dataset/{output_folder}', f'{index + 2}.png')

    # Kiểm tra nếu thư mục đích chưa tồn tại, thì tạo thư mục
    if not os.path.exists(output_folder_path):
        os.makedirs(output_folder_path)

    image.save(output_path)

print("##### CONVERT TO IMAGE DONE. ######")
# Out:
# ##### START CREATTING IMAGES ######
# ##### CONVERT TO IMAGE DONE. ######

# %% [markdown]
# MODEL TRAINING

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torchsummary import summary
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os
import matplotlib.cm as cm
import torch.utils.data as data
import random
import numpy as np

# %%
class CNNAppClassifier(nn.Module):
    def __init__(self, num_classes=15):
        super(CNNAppClassifier, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels=1, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(
            in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3 = nn.Conv2d(
            in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(32)
        self.relu3 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(32 * 3 * 3, 128)
        self.relu5 = nn.ReLU()

        self.dropout = nn.Dropout(p=0.5)

        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.pool1(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu3(x)
        x = self.pool2(x)

        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu5(x)

        x = self.dropout(x)

        x = self.fc2(x)
        return x

model = CNNAppClassifier()

# %%
data_transform = transforms.Compose([
    transforms.Resize((15, 15)),  # Chuyển đổi kích thước thành 9x9
    transforms.Grayscale(),    # Chuyển đổi thành ảnh xám
    transforms.ToTensor(),     # Chuyển đổi thành tensor
    transforms.Normalize(mean=[0.5], std=[0.5])  # Chuẩn hóa dữ liệu
])

# %%
# Đọc dataset theo thư mục (theo document của pytorch)
dataset_root = "image_dataset/app_dataset"  # Thư mục gốc chứa dataset
train_dataset = datasets.ImageFolder(
    root=dataset_root, transform=data_transform)

# %%
# Lấy danh sách các lớp (labels)
class_names = train_dataset.classes
class_names_title = train_dataset.classes

# Lấy từ điển class_to_idx từ train_dataset
class_to_idx = train_dataset.class_to_idx

# In ra các label và tên thư mục tương ứng
for label in class_names:
    idx = class_to_idx[label]
    print(f"Label: {idx}, Label's name: {label}")
# Out:
# Label: 0, Label's name: aim
# Label: 1, Label's name: bittorrent
# Label: 2, Label's name: facebook
# Label: 3, Label's name: ftps
# Label: 4, Label's name: hangouts
# Label: 5, Label's name: icq
# Label: 6, Label's name: netflix
# Label: 7, Label's name: scp
# Label: 8, Label's name: sftp
# Label: 9, Label's name: skype
# Label: 10, Label's name: spotify
# Label: 11, Label's name: vimeo
# Label: 12, Label's name: voip
# Label: 13, Label's name: youtube

# %%
# Chia Train/Validate/Test tỉ lệ 70 - 15 - 15
batch_size = 256  # Kích thước batch
total_samples = len(train_dataset)

# Set the desired fraction of the dataset you want to use (1/3 in this case)
fraction_to_use = 1
samples_to_use = int(fraction_to_use * total_samples)

# Randomly select one-third of the dataset
selected_samples = random.sample(range(total_samples), samples_to_use)

# Create a Subset of the dataset using the selected samples
train_dataset = data.Subset(train_dataset, selected_samples)
total_samples = len(train_dataset)

train_size = int((0.7 * total_samples))
validate_size = int((0.15 * total_samples))
test_size = total_samples - train_size - validate_size

print("Total", total_samples)
print("Test Amount", test_size)
print("Train Amount", train_size)
print("Validation Amount", validate_size)

train_dataset, validate_dataset, test_dataset = random_split(
    train_dataset, [train_size, validate_size, test_size])

train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_loader = DataLoader(
        test_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
validate_loader = DataLoader(
        validate_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
# Out:
# Total 227069
# Test Amount 34061
# Train Amount 158948
# Validation Amount 34060

# %%
if torch.cuda.is_available():
    gpu_count = torch.cuda.device_count()
    current_gpu = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(current_gpu)
    print(f"Have {gpu_count} GPU available.")
    print(f"GPU's name: {gpu_name}")
else:
    print("No GPU available.")
print(torch.version.cuda)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Have 1 GPU available.
# GPU's name: NVIDIA GeForce GTX 1050
# 11.7

# %%
num_epochs = 200  # Số lượng epoch
learning_rate = 0.0001

# %%
# Các giá trị cần lưu để đánh giá model
train_loss_list = []
train_accuracy_list = []
validate_loss_list = []  # Để lưu loss trên tập validate
validate_accuracy_list = []  # Để lưu accuracy trên tập validate

best_loss = float('inf')  # Giá trị loss tốt nhất
best_accuracy = 0.0  # Giá trị accuracy tốt nhất
patience = 20  # Số epoch không giảm loss hoặc không tăng accuracy cho phép trước khi dừng
no_improvement_count = 0  # Đếm số epoch không cải thiện
weight_decay = 0.0001

# %%
if torch.cuda.is_available():
    # Chuyển mô hình và dữ liệu lên GPU
    model = model.to(device)

    # Tạo hàm mất mát và tối ưu hóa trên GPU
    criterion = nn.CrossEntropyLoss().to(device)
    optimizer = torch.optim.Adam(
        model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    #optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    train_loss_list = []
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}:', end=' ')
        train_loss = 0
        correct_predictions = 0
        total_samples = 0
        model.train()
        # Lặp qua từng batch trong dữ liệu
        for images, labels in train_loader:  # train_dataloader chứa dữ liệu huấn luyện
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)  # Feed-forward
            loss = criterion(outputs, labels)  # Tính hàm mất mát

            optimizer.zero_grad()  # Xóa gradient
            loss.backward()  # Lan truyền ngược để tính gradient
            optimizer.step()  # Cập nhật trọng số mô hình
            train_loss += loss.item()  # Cost
            _, predicted = torch.max(outputs.data, 1)
            total_samples += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()

        train_accuracy = correct_predictions / total_samples
        train_accuracy_list.append(train_accuracy)
        # Lost: Trung bình cộng các Cost
        train_loss_list.append(train_loss/len(train_loader))

        # Đánh giá trên tập validate
        validate_loss = 0
        validate_correct_predictions = 0
        validate_total_samples = 0

        model.eval()  # Chuyển sang chế độ đánh giá

        for i, (images, labels) in enumerate(validate_loader):
            images = images.to(device)
            labels = labels.to(device)

            with torch.no_grad():  # Không tính đạo hàm trong quá trình đánh giá
                outputs = model(images)
                loss = criterion(outputs, labels)  # Tính hàm mất mát
                validate_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                validate_total_samples += labels.size(0)
                validate_correct_predictions += (predicted ==
                                                 labels).sum().item()

        validate_accuracy = validate_correct_predictions / validate_total_samples
        validate_accuracy_list.append(validate_accuracy)
        validate_loss_list.append(validate_loss/len(validate_loader))

        print(
            f"Training loss={train_loss_list[-1]}, Training Accuracy={train_accuracy * 100:.2f}%, "
            f"Validation loss={validate_loss_list[-1]}, Validation Accuracy={validate_accuracy * 100:.2f}%")

        if validate_loss_list[-1] >= best_loss:
            no_improvement_count += 1
        else:
            best_loss = validate_loss_list[-1]
            no_improvement_count = 0
        # Nếu không cải thiện trong số lần đã định, dừng huấn luyện
        if no_improvement_count >= patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
# Out:
# Epoch 1/200: Training loss=1.7322244897556767, Training Accuracy=42.36%, Validation loss=1.372348184905835, Validation Accuracy=55.92%
# Epoch 2/200: Training loss=1.3479407277084203, Training Accuracy=54.43%, Validation loss=1.1278547800298948, Validation Accuracy=62.29%
# Epoch 3/200: Training loss=1.1620709377786387, Training Accuracy=60.11%, Validation loss=0.9993115810316, Validation Accuracy=66.71%
# Epoch 4/200: Training loss=1.052716787310614, Training Accuracy=63.54%, Validation loss=0.9153006486038664, Validation Accuracy=68.95%
# Epoch 5/200: Training loss=0.9773197790274873, Training Accuracy=65.97%, Validation loss=0.8551898692081223, Validation Accuracy=70.38%
# Epoch 6/200: Training loss=0.9159115024042974, Training Accuracy=67.92%, Validation loss=0.8018759075385421, Validation Accuracy=71.70%
# Epoch 7/200: Training loss=0.8705994789151178, Training Accuracy=69.39%, Validation loss=0.7660350906315134, Validation Accuracy=73.14%
# Epoch 8/200: Training loss=0.8306993241279406, Training Accuracy=70.74%, Validation loss=0.7360643584336808, Validation Accuracy=73.90%
# Epoch 9/200: Training loss=0.7991481702684781, Training Accuracy=71.67%, Validation loss=0.7034351645565745, Validation Accuracy=74.84%
# Epoch 10/200: Training loss=0.7743941043502083, Training Accuracy=72.54%, Validation loss=0.6831646978632727, Validation Accuracy=75.55%
# Epoch 11/200: Training loss=0.7486234504051639, Training Accuracy=73.42%, Validation loss=0.6718531348812047, Validation Accuracy=76.27%
# Epoch 12/200: Training loss=0.7280071382553297, Training Accuracy=74.22%, Validation loss=0.6564769400144691, Validation Accuracy=76.79%
# Epoch 13/200: Training loss=0.7104570575766326, Training Accuracy=74.58%, Validation loss=0.6374271676611545, Validation Accuracy=77.25%
# Epoch 14/200: Training loss=0.6921854766862596, Training Accuracy=75.24%, Validation loss=0.632990058900705, Validation Accuracy=77.63%
# Epoch 15/200: Training loss=0.6770119477009428, Training Accuracy=75.66%, Validation loss=0.5989803390494034, Validation Accuracy=78.25%
# Epoch 16/200: Training loss=0.6648675877115001, Training Accuracy=76.22%, Validation loss=0.5922829662241152, Validation Accuracy=79.01%
# Epoch 17/200: Training loss=0.6511440707097691, Training Accuracy=76.75%, Validation loss=0.5850658069795637, Validation Accuracy=78.66%
# Epoch 18/200: Training loss=0.6411959858140316, Training Accuracy=77.06%, Validation loss=0.573213160927616, Validation Accuracy=79.54%
# Epoch 19/200: Training loss=0.6293988563300331, Training Accuracy=77.30%, Validation loss=0.5586065040595496, Validation Accuracy=79.92%
# Epoch 20/200: Training loss=0.6174765890539172, Training Accuracy=77.92%, Validation loss=0.5590384549169398, Validation Accuracy=79.99%
# Epoch 21/200: Training loss=0.6109762995139413, Training Accuracy=78.05%, Validation loss=0.5499621807639279, Validation Accuracy=80.22%
# Epoch 22/200: Training loss=0.6016228252274979, Training Accuracy=78.38%, Validation loss=0.5416081454326858, Validation Accuracy=80.73%
# Epoch 23/200: Training loss=0.5918095754444503, Training Accuracy=78.70%, Validation loss=0.5351211951294942, Validation Accuracy=80.76%
# Epoch 24/200: Training loss=0.5870561819529572, Training Accuracy=78.80%, Validation loss=0.529043021931577, Validation Accuracy=80.58%
# Epoch 25/200: Training loss=0.5786061357472829, Training Accuracy=79.20%, Validation loss=0.5395983057235604, Validation Accuracy=80.73%
# Epoch 26/200: Training loss=0.5694157366495394, Training Accuracy=79.44%, Validation loss=0.517768368792178, Validation Accuracy=81.29%
# Epoch 27/200: Training loss=0.5659093732995112, Training Accuracy=79.59%, Validation loss=0.5150898928517726, Validation Accuracy=81.40%
# Epoch 28/200: Training loss=0.5587300344365806, Training Accuracy=79.94%, Validation loss=0.5100180213131121, Validation Accuracy=81.69%
# Epoch 29/200: Training loss=0.5536641563962239, Training Accuracy=80.11%, Validation loss=0.5103678756685399, Validation Accuracy=81.56%
# Epoch 30/200: Training loss=0.5499011791654639, Training Accuracy=80.09%, Validation loss=0.5007556423322478, Validation Accuracy=82.27%
# Epoch 31/200: Training loss=0.5409836983623136, Training Accuracy=80.39%, Validation loss=0.49600226976978246, Validation Accuracy=82.09%
# Epoch 32/200: Training loss=0.5385397096283002, Training Accuracy=80.42%, Validation loss=0.4887941190555914, Validation Accuracy=82.10%
# Epoch 33/200: Training loss=0.5339978261942256, Training Accuracy=80.56%, Validation loss=0.4805762783360125, Validation Accuracy=82.46%
# Epoch 34/200: Training loss=0.5295191115419262, Training Accuracy=80.75%, Validation loss=0.4873525353509988, Validation Accuracy=82.38%
# Epoch 35/200: Training loss=0.5240069571612538, Training Accuracy=81.11%, Validation loss=0.4815470832052515, Validation Accuracy=82.60%
# Epoch 36/200: Training loss=0.5199063915081454, Training Accuracy=81.17%, Validation loss=0.4713518770773019, Validation Accuracy=82.63%
# Epoch 37/200: Training loss=0.5168296797455989, Training Accuracy=81.42%, Validation loss=0.4785033751334717, Validation Accuracy=82.70%
# Epoch 38/200: Training loss=0.5121651483810659, Training Accuracy=81.35%, Validation loss=0.47461031710923607, Validation Accuracy=83.09%
# Epoch 39/200: Training loss=0.508981649906355, Training Accuracy=81.52%, Validation loss=0.46021476966231617, Validation Accuracy=83.41%
# Epoch 40/200: Training loss=0.5048026722794378, Training Accuracy=81.72%, Validation loss=0.4719376455047237, Validation Accuracy=82.87%
# Epoch 41/200: Training loss=0.5021496772190223, Training Accuracy=81.89%, Validation loss=0.46645996819681196, Validation Accuracy=83.05%
# Epoch 42/200: Training loss=0.49949054244827723, Training Accuracy=81.89%, Validation loss=0.4645910320886925, Validation Accuracy=82.99%
# Epoch 43/200: Training loss=0.49652166532625513, Training Accuracy=81.93%, Validation loss=0.4531281205700405, Validation Accuracy=83.39%
# Epoch 44/200: Training loss=0.49338230471488165, Training Accuracy=82.11%, Validation loss=0.46053389237443015, Validation Accuracy=83.31%
# Epoch 45/200: Training loss=0.4899117489751794, Training Accuracy=82.18%, Validation loss=0.4517887284729018, Validation Accuracy=83.85%
# Epoch 46/200: Training loss=0.4863923768394427, Training Accuracy=82.34%, Validation loss=0.4589571912786854, Validation Accuracy=83.52%
# Epoch 47/200: Training loss=0.48519218342315745, Training Accuracy=82.35%, Validation loss=0.45016719067274635, Validation Accuracy=83.68%
# Epoch 48/200: Training loss=0.4814201514694042, Training Accuracy=82.37%, Validation loss=0.44972922374953084, Validation Accuracy=83.68%
# Epoch 49/200: Training loss=0.4806643096241206, Training Accuracy=82.56%, Validation loss=0.464621345721074, Validation Accuracy=83.20%
# Epoch 50/200: Training loss=0.4768707425410045, Training Accuracy=82.62%, Validation loss=0.45005212690848023, Validation Accuracy=83.38%
# Epoch 51/200: Training loss=0.47344665514866124, Training Accuracy=82.75%, Validation loss=0.44714516178885505, Validation Accuracy=83.73%
# Epoch 52/200: Training loss=0.47223115322478537, Training Accuracy=82.83%, Validation loss=0.44271039228830766, Validation Accuracy=83.88%
# Epoch 53/200: Training loss=0.4705499886218668, Training Accuracy=82.87%, Validation loss=0.46171051419492976, Validation Accuracy=83.73%
# Epoch 54/200: Training loss=0.4658618593369513, Training Accuracy=83.02%, Validation loss=0.443987018804052, Validation Accuracy=83.81%
# Epoch 55/200: Training loss=0.46537806878343296, Training Accuracy=83.01%, Validation loss=0.43822674186372046, Validation Accuracy=83.98%
# Epoch 56/200: Training loss=0.46304835035989056, Training Accuracy=83.03%, Validation loss=0.43797412514686584, Validation Accuracy=84.09%
# Epoch 57/200: Training loss=0.46302688784069485, Training Accuracy=83.04%, Validation loss=0.4296140166194136, Validation Accuracy=84.30%
# Epoch 58/200: Training loss=0.4598201144240713, Training Accuracy=83.32%, Validation loss=0.4419753461408971, Validation Accuracy=83.91%
# Epoch 59/200: Training loss=0.45745940619236797, Training Accuracy=83.35%, Validation loss=0.4338202941328732, Validation Accuracy=84.23%
# Epoch 60/200: Training loss=0.45420090079115594, Training Accuracy=83.31%, Validation loss=0.44106934075035265, Validation Accuracy=84.07%
# Epoch 61/200: Training loss=0.4525992993667314, Training Accuracy=83.54%, Validation loss=0.424602412465793, Validation Accuracy=84.52%
# Epoch 62/200: Training loss=0.4524047498061845, Training Accuracy=83.45%, Validation loss=0.4349970488405939, Validation Accuracy=84.47%
# Epoch 63/200: Training loss=0.45072372452072473, Training Accuracy=83.49%, Validation loss=0.4215924828799803, Validation Accuracy=84.62%
# Epoch 64/200: Training loss=0.4491783953519259, Training Accuracy=83.56%, Validation loss=0.42838691019300207, Validation Accuracy=84.69%
# Epoch 65/200: Training loss=0.44760286563260543, Training Accuracy=83.54%, Validation loss=0.4194019280040442, Validation Accuracy=84.72%
# Epoch 66/200: Training loss=0.44598066475656295, Training Accuracy=83.66%, Validation loss=0.42044800898032403, Validation Accuracy=84.69%
# Epoch 67/200: Training loss=0.4440099630570834, Training Accuracy=83.74%, Validation loss=0.4235668449259516, Validation Accuracy=84.70%
# Epoch 68/200: Training loss=0.4430330258924604, Training Accuracy=83.75%, Validation loss=0.421129357903751, Validation Accuracy=84.57%
# Epoch 69/200: Training loss=0.44138390430505725, Training Accuracy=83.76%, Validation loss=0.4197143689909978, Validation Accuracy=84.69%
# Epoch 70/200: Training loss=0.4378994608270949, Training Accuracy=83.85%, Validation loss=0.4246795836891701, Validation Accuracy=84.57%
# Epoch 71/200: Training loss=0.43717042797045624, Training Accuracy=83.91%, Validation loss=0.42402378091616416, Validation Accuracy=84.56%
# Epoch 72/200: Training loss=0.43408407302102414, Training Accuracy=83.99%, Validation loss=0.41742798285697824, Validation Accuracy=84.51%
# Epoch 73/200: Training loss=0.43421045737566005, Training Accuracy=83.96%, Validation loss=0.42118025092936273, Validation Accuracy=84.74%
# Epoch 74/200: Training loss=0.4339052330756533, Training Accuracy=84.01%, Validation loss=0.4148707708983279, Validation Accuracy=84.93%
# Epoch 75/200: Training loss=0.4314730990432119, Training Accuracy=84.28%, Validation loss=0.4205909733896825, Validation Accuracy=85.01%
# Epoch 76/200: Training loss=0.4298111801658084, Training Accuracy=84.12%, Validation loss=0.4125408107665048, Validation Accuracy=84.93%
# Epoch 77/200: Training loss=0.4290295348363222, Training Accuracy=84.21%, Validation loss=0.40804397670635534, Validation Accuracy=85.03%
# Epoch 78/200: Training loss=0.42752025798323073, Training Accuracy=84.28%, Validation loss=0.4199592864780284, Validation Accuracy=85.01%
# Epoch 79/200: Training loss=0.4274791354334489, Training Accuracy=84.31%, Validation loss=0.4171404324805559, Validation Accuracy=84.93%
# Epoch 80/200: Training loss=0.42489610058098026, Training Accuracy=84.38%, Validation loss=0.4107044152359464, Validation Accuracy=84.93%
# Epoch 81/200: Training loss=0.42372768258319, Training Accuracy=84.30%, Validation loss=0.4106695743194267, Validation Accuracy=85.27%
# Epoch 82/200: Training loss=0.42438065103478667, Training Accuracy=84.38%, Validation loss=0.4146208709745265, Validation Accuracy=85.06%
# Epoch 83/200: Training loss=0.4219135241807947, Training Accuracy=84.39%, Validation loss=0.4061465887213821, Validation Accuracy=85.21%
# Epoch 84/200: Training loss=0.4210616147172624, Training Accuracy=84.49%, Validation loss=0.4105233095808705, Validation Accuracy=85.27%
# Epoch 85/200: Training loss=0.4196565653198967, Training Accuracy=84.55%, Validation loss=0.41367427582171423, Validation Accuracy=85.02%
# Epoch 86/200: Training loss=0.4182257516948497, Training Accuracy=84.63%, Validation loss=0.41173544615062313, Validation Accuracy=84.94%
# Epoch 87/200: Training loss=0.4178476157971626, Training Accuracy=84.61%, Validation loss=0.4106984243019303, Validation Accuracy=84.89%
# Epoch 88/200: Training loss=0.41715581573533933, Training Accuracy=84.54%, Validation loss=0.42176459551747164, Validation Accuracy=84.47%
# Epoch 89/200: Training loss=0.41553478607616945, Training Accuracy=84.65%, Validation loss=0.4199202245295937, Validation Accuracy=84.60%
# Epoch 90/200: Training loss=0.41358501549312265, Training Accuracy=84.73%, Validation loss=0.4209466872375403, Validation Accuracy=84.90%
# Epoch 91/200: Training loss=0.41434410526364707, Training Accuracy=84.73%, Validation loss=0.41396420126530664, Validation Accuracy=85.25%
# Epoch 92/200: Training loss=0.41381421862784984, Training Accuracy=84.62%, Validation loss=0.41002183307462664, Validation Accuracy=85.31%
# Epoch 93/200: Training loss=0.41229639997804796, Training Accuracy=84.75%, Validation loss=0.4023378637633217, Validation Accuracy=85.40%
# Epoch 94/200: Training loss=0.41285890144042536, Training Accuracy=84.74%, Validation loss=0.4038395492443398, Validation Accuracy=85.34%
# Epoch 95/200: Training loss=0.4103177347236977, Training Accuracy=84.79%, Validation loss=0.40745097832448446, Validation Accuracy=85.50%
# Epoch 96/200: Training loss=0.40800879168625614, Training Accuracy=84.87%, Validation loss=0.3991497145659888, Validation Accuracy=85.62%
# Epoch 97/200: Training loss=0.4084271254458865, Training Accuracy=84.85%, Validation loss=0.4007125883849699, Validation Accuracy=85.39%
# Epoch 98/200: Training loss=0.40852273849473486, Training Accuracy=84.87%, Validation loss=0.40323284424062983, Validation Accuracy=85.39%
# Epoch 99/200: Training loss=0.4053837514921855, Training Accuracy=84.96%, Validation loss=0.3972411094539201, Validation Accuracy=85.70%
# Epoch 100/200: Training loss=0.4056899477990161, Training Accuracy=85.04%, Validation loss=0.39987762961814655, Validation Accuracy=85.53%
# Epoch 101/200: Training loss=0.4063935477088615, Training Accuracy=84.83%, Validation loss=0.4073921577699149, Validation Accuracy=85.44%
# Epoch 102/200: Training loss=0.4044496353217753, Training Accuracy=84.98%, Validation loss=0.3961540500619518, Validation Accuracy=85.86%
# Epoch 103/200: Training loss=0.4031271738226671, Training Accuracy=85.07%, Validation loss=0.4037636135941121, Validation Accuracy=85.51%
# Epoch 104/200: Training loss=0.40287644261323313, Training Accuracy=85.04%, Validation loss=0.39454398048457817, Validation Accuracy=85.65%
# Epoch 105/200: Training loss=0.4014095727852193, Training Accuracy=85.07%, Validation loss=0.39165008101445525, Validation Accuracy=85.81%
# Epoch 106/200: Training loss=0.399082172775998, Training Accuracy=85.13%, Validation loss=0.39402839613716995, Validation Accuracy=85.66%
# Epoch 107/200: Training loss=0.40016586135550974, Training Accuracy=85.17%, Validation loss=0.39976897079553175, Validation Accuracy=85.51%
# Epoch 108/200: Training loss=0.40104290295914174, Training Accuracy=85.10%, Validation loss=0.3929694129237488, Validation Accuracy=85.82%
# Epoch 109/200: Training loss=0.39954355267894825, Training Accuracy=85.18%, Validation loss=0.392864770631292, Validation Accuracy=85.92%
# Epoch 110/200: Training loss=0.39772142755428563, Training Accuracy=85.20%, Validation loss=0.40096412924354646, Validation Accuracy=85.57%
# Epoch 111/200: Training loss=0.3978104521782886, Training Accuracy=85.19%, Validation loss=0.3939200579675276, Validation Accuracy=85.48%
# Epoch 112/200: Training loss=0.3978499400394934, Training Accuracy=85.24%, Validation loss=0.396419800261953, Validation Accuracy=85.65%
# Epoch 113/200: Training loss=0.3956268381765307, Training Accuracy=85.30%, Validation loss=0.38909581614964045, Validation Accuracy=85.85%
# Epoch 114/200: Training loss=0.39457333131112915, Training Accuracy=85.33%, Validation loss=0.4069361169614009, Validation Accuracy=85.34%
# Epoch 115/200: Training loss=0.3940816647860547, Training Accuracy=85.31%, Validation loss=0.4005523127739999, Validation Accuracy=85.52%
# Epoch 116/200: Training loss=0.39343338674489237, Training Accuracy=85.46%, Validation loss=0.3945343916985526, Validation Accuracy=85.57%
# Epoch 117/200: Training loss=0.39292139832332323, Training Accuracy=85.38%, Validation loss=0.3906201460579438, Validation Accuracy=85.82%
# Epoch 118/200: Training loss=0.3924690596819308, Training Accuracy=85.44%, Validation loss=0.3951582385977702, Validation Accuracy=85.66%
# Epoch 119/200: Training loss=0.39276654895952934, Training Accuracy=85.36%, Validation loss=0.38748226503827676, Validation Accuracy=85.99%
# Epoch 120/200: Training loss=0.39100666185795974, Training Accuracy=85.48%, Validation loss=0.3920424426002289, Validation Accuracy=86.08%
# Epoch 121/200: Training loss=0.3912367100396978, Training Accuracy=85.33%, Validation loss=0.3917247667463858, Validation Accuracy=85.52%
# Epoch 122/200: Training loss=0.3903489119572724, Training Accuracy=85.47%, Validation loss=0.38174412755379034, Validation Accuracy=86.13%
# Epoch 123/200: Training loss=0.39125760938618304, Training Accuracy=85.32%, Validation loss=0.4035322850764687, Validation Accuracy=85.68%
# Epoch 124/200: Training loss=0.3900242233094002, Training Accuracy=85.48%, Validation loss=0.38844535977982764, Validation Accuracy=85.71%
# Epoch 125/200: Training loss=0.38750174252883246, Training Accuracy=85.55%, Validation loss=0.39334515693472394, Validation Accuracy=85.94%
# Epoch 126/200: Training loss=0.388578145928237, Training Accuracy=85.49%, Validation loss=0.3974659783737873, Validation Accuracy=85.78%
# Epoch 127/200: Training loss=0.3877540221632775, Training Accuracy=85.65%, Validation loss=0.4193088950505897, Validation Accuracy=85.26%
# Epoch 128/200: Training loss=0.38726246270580567, Training Accuracy=85.55%, Validation loss=0.3908124441531167, Validation Accuracy=86.32%
# Epoch 129/200: Training loss=0.38505017565452343, Training Accuracy=85.50%, Validation loss=0.39465525212572583, Validation Accuracy=85.87%
# Epoch 130/200: Training loss=0.3874666773850599, Training Accuracy=85.56%, Validation loss=0.38917775452136993, Validation Accuracy=86.24%
# Epoch 131/200: Training loss=0.38529670943960476, Training Accuracy=85.64%, Validation loss=0.3891457219177218, Validation Accuracy=85.83%
# Epoch 132/200: Training loss=0.38441885067164994, Training Accuracy=85.73%, Validation loss=0.3860674519369851, Validation Accuracy=86.14%
# Epoch 133/200: Training loss=0.3841178965261401, Training Accuracy=85.66%, Validation loss=0.37732140625368304, Validation Accuracy=86.23%
# Epoch 134/200: Training loss=0.38323803164436815, Training Accuracy=85.66%, Validation loss=0.3858735114336014, Validation Accuracy=86.26%
# Epoch 135/200: Training loss=0.3831012023915799, Training Accuracy=85.66%, Validation loss=0.39334265365084603, Validation Accuracy=85.52%
# Epoch 136/200: Training loss=0.3829481274417441, Training Accuracy=85.72%, Validation loss=0.38661408780226064, Validation Accuracy=85.74%
# Epoch 137/200: Training loss=0.38177327310213527, Training Accuracy=85.71%, Validation loss=0.3987106789848698, Validation Accuracy=85.56%
# Epoch 138/200: Training loss=0.38061877365273555, Training Accuracy=85.80%, Validation loss=0.38955684673430313, Validation Accuracy=85.98%
# Epoch 139/200: Training loss=0.38059103536912975, Training Accuracy=85.70%, Validation loss=0.3851822268829417, Validation Accuracy=86.05%
# Epoch 140/200: Training loss=0.3794482946395874, Training Accuracy=85.76%, Validation loss=0.38581849551245345, Validation Accuracy=86.27%
# Epoch 141/200: Training loss=0.37915074227800694, Training Accuracy=85.82%, Validation loss=0.3782533527310215, Validation Accuracy=86.10%
# Epoch 142/200: Training loss=0.37850438003186826, Training Accuracy=85.85%, Validation loss=0.38376213465608766, Validation Accuracy=86.07%
# Epoch 143/200: Training loss=0.38096059402885835, Training Accuracy=85.81%, Validation loss=0.3876896581765431, Validation Accuracy=86.20%
# Epoch 144/200: Training loss=0.37885850092063206, Training Accuracy=85.81%, Validation loss=0.3823836750503796, Validation Accuracy=86.44%
# Epoch 145/200: Training loss=0.37752113499695167, Training Accuracy=85.86%, Validation loss=0.3815889469723203, Validation Accuracy=86.16%
# Epoch 146/200: Training loss=0.3792425175699827, Training Accuracy=85.78%, Validation loss=0.38887913147015357, Validation Accuracy=86.10%
# Epoch 147/200: Training loss=0.37773150042443265, Training Accuracy=85.90%, Validation loss=0.3867733082664547, Validation Accuracy=85.87%
# Epoch 148/200: Training loss=0.3782518400470224, Training Accuracy=85.88%, Validation loss=0.38416335609421803, Validation Accuracy=86.03%
# Epoch 149/200: Training loss=0.3756834967796737, Training Accuracy=85.83%, Validation loss=0.3918411296917431, Validation Accuracy=86.10%
# Epoch 150/200: Training loss=0.37560864942277306, Training Accuracy=85.87%, Validation loss=0.3834328691461193, Validation Accuracy=86.21%
# Epoch 151/200: Training loss=0.3765317264482403, Training Accuracy=85.90%, Validation loss=0.4008125554381022, Validation Accuracy=85.73%
# Epoch 152/200: Training loss=0.37489484233748704, Training Accuracy=85.90%, Validation loss=0.38470171013874793, Validation Accuracy=86.18%
# Epoch 153/200: Training loss=0.37508146426431993, Training Accuracy=85.86%, Validation loss=0.3912886781478996, Validation Accuracy=86.04%
# Early stopping at epoch 153

# %%
model_save_path = "GUI/models/app_classification_2.pth"
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_list': train_loss_list,
    'validate_loss_list': validate_loss_list,
    'train_accuracy_list': train_accuracy_list,
    'validate_accuracy_list': validate_accuracy_list
}, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to GUI/models/app_classification_2.pth

# %%
model_save_path = "GUI/models/app_classification.pth"
# Load lại model
model = CNNAppClassifier()
model = model.to(device)
optimizer = torch.optim.Adam(
    model.parameters(), lr=learning_rate, weight_decay=weight_decay)

checkpoint = torch.load(model_save_path)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

train_loss_list = checkpoint['train_loss_list']
validate_loss_list = checkpoint['validate_loss_list']
train_accuracy_list = checkpoint['train_accuracy_list']
validate_accuracy_list = checkpoint['validate_accuracy_list']

# %% [markdown]
# Dự đoán trên tập test

# %%
model.eval()  # Chuyển mô hình sang chế độ đánh giá
correct_predictions = 0
total_samples = 0
all_predictions = []
all_labels = []

# Khởi tạo danh sách để lưu trữ xác suất dự đoán cho từng lớp
all_probs = []

with torch.no_grad():  # Tắt tính toán gradient trong quá trình đánh giá
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)  # Feed-forward
        _, predicted = torch.max(outputs.data, 1)
        total_samples += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        probs = torch.nn.functional.softmax(outputs, dim=1)
        all_probs.extend(probs.cpu().numpy())

test_accuracy = correct_predictions / total_samples
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
all_probs = np.array(all_probs)

label_to_class_name = {index: class_name for index,
                       class_name in enumerate(class_names_title)}
label_display = [label_to_class_name[label]
                 for label in range(len(class_names_title))]

for label, class_name in enumerate(label_display):
    print(f"Label {label}: {class_name}")
# Out:
# Test Accuracy: 88.44%
# Label 0: aim
# Label 1: bittorrent
# Label 2: facebook
# Label 3: ftps
# Label 4: hangouts
# Label 5: icq
# Label 6: netflix
# Label 7: scp
# Label 8: sftp
# Label 9: skype
# Label 10: spotify
# Label 11: vimeo
# Label 12: voip
# Label 13: youtube

# %%
# Tính confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# In ra confusion matrix
class_names = [str(i) for i in range(len(cm))]
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="g",
            xticklabels=class_names, yticklabels=class_names)

for i in range(len(class_names)):
    plt.text(i + 0.5, i + 0.5, cm[i, i], ha="center",
             va="center", color="black")

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Tính confusion matrix theo tỉ số
cm = confusion_matrix(all_labels, all_predictions)

# Chuyển ma trận nhầm lẫn sang dạng phần trăm
# Chia mỗi hàng cho tổng của hàng đó
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# In ra confusion matrix dưới dạng phần trăm
plt.figure(figsize=(8, 6))
sns.heatmap(cm_percentage, annot=True, fmt=".2f", cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)

for i in range(len(class_names)):
    plt.text(i + 0.5, i + 0.5,
             f"{cm[i, i] / sum(cm[i, :]):.2f}", ha="center", va="center", color="red")

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (Percentage)')
plt.show()

# %% [markdown]
# Phân tích trên đồ thị

# %%
epochs = range(1, len(train_accuracy_list) + 1)
# Độ chính xác trên tập huấn luyện và tập validate
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_accuracy_list, 'b', label='Train Accuracy')
plt.plot(epochs, validate_accuracy_list, 'r', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss_list, 'b', label='Train Loss')
plt.plot(epochs, validate_loss_list, 'r', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Đánh giá model theo từng đại lượng

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, auc
import pandas as pd

# %%
# Tính Precision, Recall, và F1-Score cho từng lớp
precisions = precision_score(all_labels, all_predictions, average=None)
recalls = recall_score(all_labels, all_predictions, average=None)
f1_scores = f1_score(all_labels, all_predictions, average=None)

accuracies = []
for label in range(len(class_names_title)):
    indices = [i for i, l in enumerate(all_labels) if l == label]
    label_predictions = [all_predictions[i] for i in indices]
    label_true = [all_labels[i] for i in indices]
    accuracy = accuracy_score(label_true, label_predictions)
    accuracies.append(accuracy)

data = {'Class': label_display, 'Precision': precisions,
        'Recall': recalls, 'F1-Score': f1_scores, 'Accuracy': accuracies}
df = pd.DataFrame(data)

average_precision = np.mean(precisions)
average_recall = np.mean(recalls)
average_f1_score = np.mean(f1_scores)

print(df)
print("Model's precision", average_precision)
print("Model's recall", average_recall)
print("Model's f1-score",average_f1_score)
print(f"Model's Accuracy: {test_accuracy}%")
# Out:
#          Class  Precision    Recall  F1-Score  Accuracy
# 0          aim   0.708712  0.761808  0.734301  0.761808
# 1   bittorrent   0.995150  0.998783  0.996963  0.998783
# 2     facebook   0.918420  0.746767  0.823746  0.746767
# 3         ftps   0.988158  0.928689  0.957501  0.928689
# 4     hangouts   0.906498  0.927818  0.917034  0.927818
# 5          icq   0.729299  0.648725  0.686657  0.648725
# 6      netflix   0.949061  0.938093  0.943545  0.938093
# 7          scp   0.974532  0.987102  0.980777  0.987102
# 8         sftp   0.931669  0.925234  0.928440  0.925234
# 9        skype   0.840153  0.852878  0.846468  0.852878
# 10     spotify   0.891148  0.942243  0.915984  0.942243
# 11       vimeo   0.946246  0.923782  0.934879  0.923782
# 12        voip   0.743719  0.903541  0.815877  0.903541
# 13     youtube   0.899634  0.894907  0.897264  0.894907
# Model's precision 0.8873142162859947
# Model's recall 0.8843120910818774
# Model's f1-score 0.8842453955892571
# Model's Accuracy: 0.8844132585655148%

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(len(class_names_title)):
    fpr[i], tpr[i], _ = roc_curve(all_labels, all_probs[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])
    print(f'AUC for {class_names_title[i]}: {roc_auc[i]:.2f}')

plt.figure(figsize=(8, 6))
for i, class_name in enumerate(class_names_title):
    plt.plot(fpr[i], tpr[i], lw=2,
             label=f'ROC curve for {class_name} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC for aim: 0.99
# AUC for bittorrent: 1.00
# AUC for facebook: 0.99
# AUC for ftps: 1.00
# AUC for hangouts: 1.00
# AUC for icq: 0.98
# AUC for netflix: 1.00
# AUC for scp: 1.00
# AUC for sftp: 1.00
# AUC for skype: 0.99
# AUC for spotify: 1.00
# AUC for vimeo: 1.00
# AUC for voip: 0.99
# AUC for youtube: 1.00

# %% [markdown]
# Transfer learning

# %%
import torchvision.transforms as transforms
import torch.nn as nn
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import models
from torch.utils.data import random_split
import random
import torch.utils.data as data
import torch
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# %%
data_transform = transforms.Compose([
    transforms.Resize((70, 70)),
    transforms.Grayscale(num_output_channels=3), # Chuyển đổi thành ảnh xám, 3 kênh màu xám
    transforms.ToTensor(),     # Chuyển đổi thành tensor
    transforms.Normalize(mean=[0.5], std=[0.5])  # Chuẩn hóa dữ liệu
])

# %%
dataset_root = "image_dataset/app_dataset/"  # Thư mục gốc chứa dataset
train_dataset = ImageFolder(
    root=dataset_root, transform=data_transform)
print(train_dataset.classes)
# Out:
# ['aim', 'bittorrent', 'facebook', 'ftps', 'hangouts', 'icq', 'netflix', 'scp', 'sftp', 'skype', 'spotify', 'vimeo', 'voip', 'youtube']

# %%
batch_size = 512  # Kích thước batch
total_samples = len(train_dataset)

# Chia lượng data được sử dụng
fraction_to_use = 1
samples_to_use = int(fraction_to_use * total_samples)

# Lấy datata random theo tỉ lệ
selected_samples = random.sample(range(total_samples), samples_to_use)

# Tạo ra các subset trên mỗi sample
train_dataset = data.Subset(train_dataset, selected_samples)
total_samples = len(train_dataset)

train_size = int(0.7 * total_samples)
validate_size = int(0.15 * total_samples)
test_size = total_samples - train_size - validate_size

print("Total", total_samples)
print("Test Amount", test_size)
print("Train Amount", train_size)
print("Validation Amount", validate_size)

train_dataset, validate_dataset, test_dataset = random_split(
    train_dataset, [train_size, validate_size, test_size])

# Tạo DataLoader sử dụng pin_memory để tăng hiệu suất nếu cần thiết
train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_loader = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
validate_loader = DataLoader(
    validate_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
# Out:
# Total 227069
# Test Amount 34061
# Train Amount 158948
# Validation Amount 34060

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# RestNet50

# %%
resnet50 = models.resnet50(pretrained=True)
# Fine tuning
for param in resnet50.parameters():
    param.requires_grad = False
num_classes = 14
fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes), 
    nn.LogSoftmax(dim=1)
)

# %%
learning_rate = 0.0001
num_epochs = 100
weight_decay = 0.001

# %%
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(
        resnet50.fc.parameters(), lr=learning_rate, weight_decay=weight_decay)

# %%
# Các giá trị cần lưu để đánh giá model
train_loss_list = []
train_accuracy_list = []
validate_loss_list = []  # Để lưu loss trên tập validate
validate_accuracy_list = []  # Để lưu accuracy trên tập validate

best_loss = float('inf')  # Giá trị loss tốt nhất
patience = 5  # Số epoch không giảm loss hoặc không tăng accuracy cho phép trước khi dừng
no_improvement_count = 0  # Đếm số epoch không cải thiện

# %%
resnet50.to(device)
for epoch in range(num_epochs):
    resnet50.train()
    total_train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = resnet50(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = correct_train / total_train
    average_train_loss = total_train_loss / len(train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(average_train_loss)

    # Validation
    resnet50.eval()
    total_validation_loss = 0.0
    correct_validation = 0
    total_validation = 0
    
    with torch.no_grad():
        for inputs, labels in validate_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = resnet50(inputs)
            loss = criterion(outputs, labels)
            
            total_validation_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
    
    validation_accuracy = correct_validation / total_validation
    average_validation_loss = total_validation_loss / len(validate_loader)
    validate_accuracy_list.append(validation_accuracy)
    validate_loss_list.append(average_validation_loss)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {average_train_loss:.4f}, Train Accuracy: {100 * train_accuracy:.2f}%, Validation Loss: {average_validation_loss:.4f}, Validation Accuracy: {100 * validation_accuracy:.2f}%')

    if validate_loss_list[-1] >= best_loss:
        no_improvement_count += 1
    else:
        best_loss = validate_loss_list[-1]
        no_improvement_count = 0
        # Nếu không cải thiện trong số lần đã định, dừng huấn luyện
    if no_improvement_count >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        break
# Out:
# Epoch 1/100, Train Loss: 2.1348, Train Accuracy: 30.89%, Validation Loss: 1.8306, Validation Accuracy: 41.54%
# Epoch 2/100, Train Loss: 1.8391, Train Accuracy: 40.18%, Validation Loss: 1.6987, Validation Accuracy: 44.94%
# Epoch 3/100, Train Loss: 1.7402, Train Accuracy: 43.18%, Validation Loss: 1.6250, Validation Accuracy: 46.81%
# Epoch 4/100, Train Loss: 1.6790, Train Accuracy: 45.04%, Validation Loss: 1.5761, Validation Accuracy: 48.08%
# Epoch 5/100, Train Loss: 1.6332, Train Accuracy: 46.30%, Validation Loss: 1.5402, Validation Accuracy: 48.75%
# Epoch 6/100, Train Loss: 1.5958, Train Accuracy: 47.57%, Validation Loss: 1.5076, Validation Accuracy: 50.16%
# Epoch 7/100, Train Loss: 1.5660, Train Accuracy: 48.35%, Validation Loss: 1.4777, Validation Accuracy: 51.08%
# Epoch 8/100, Train Loss: 1.5392, Train Accuracy: 49.03%, Validation Loss: 1.4566, Validation Accuracy: 51.53%
# Epoch 9/100, Train Loss: 1.5148, Train Accuracy: 49.81%, Validation Loss: 1.4281, Validation Accuracy: 52.46%
# Epoch 10/100, Train Loss: 1.4929, Train Accuracy: 50.54%, Validation Loss: 1.4144, Validation Accuracy: 52.93%
# Epoch 11/100, Train Loss: 1.4735, Train Accuracy: 51.11%, Validation Loss: 1.3924, Validation Accuracy: 53.45%
# Epoch 12/100, Train Loss: 1.4568, Train Accuracy: 51.49%, Validation Loss: 1.3755, Validation Accuracy: 53.97%
# Epoch 13/100, Train Loss: 1.4432, Train Accuracy: 51.95%, Validation Loss: 1.3641, Validation Accuracy: 54.37%
# Epoch 14/100, Train Loss: 1.4278, Train Accuracy: 52.34%, Validation Loss: 1.3487, Validation Accuracy: 54.83%
# Epoch 15/100, Train Loss: 1.4130, Train Accuracy: 52.81%, Validation Loss: 1.3375, Validation Accuracy: 55.45%
# Epoch 16/100, Train Loss: 1.3982, Train Accuracy: 53.22%, Validation Loss: 1.3217, Validation Accuracy: 55.71%
# Epoch 17/100, Train Loss: 1.3874, Train Accuracy: 53.76%, Validation Loss: 1.3102, Validation Accuracy: 56.09%
# Epoch 18/100, Train Loss: 1.3769, Train Accuracy: 54.01%, Validation Loss: 1.2992, Validation Accuracy: 56.34%
# Epoch 19/100, Train Loss: 1.3685, Train Accuracy: 54.12%, Validation Loss: 1.2915, Validation Accuracy: 56.98%
# Epoch 20/100, Train Loss: 1.3572, Train Accuracy: 54.60%, Validation Loss: 1.2842, Validation Accuracy: 56.63%
# Epoch 21/100, Train Loss: 1.3451, Train Accuracy: 54.82%, Validation Loss: 1.2749, Validation Accuracy: 57.51%
# Epoch 22/100, Train Loss: 1.3376, Train Accuracy: 55.19%, Validation Loss: 1.2647, Validation Accuracy: 57.53%
# Epoch 23/100, Train Loss: 1.3283, Train Accuracy: 55.46%, Validation Loss: 1.2554, Validation Accuracy: 57.71%
# Epoch 24/100, Train Loss: 1.3207, Train Accuracy: 55.64%, Validation Loss: 1.2495, Validation Accuracy: 58.09%
# Epoch 25/100, Train Loss: 1.3131, Train Accuracy: 55.95%, Validation Loss: 1.2437, Validation Accuracy: 58.25%
# Epoch 26/100, Train Loss: 1.3065, Train Accuracy: 56.06%, Validation Loss: 1.2344, Validation Accuracy: 58.85%
# Epoch 27/100, Train Loss: 1.2961, Train Accuracy: 56.52%, Validation Loss: 1.2272, Validation Accuracy: 58.61%
# Epoch 28/100, Train Loss: 1.2916, Train Accuracy: 56.57%, Validation Loss: 1.2199, Validation Accuracy: 58.86%
# Epoch 29/100, Train Loss: 1.2835, Train Accuracy: 56.66%, Validation Loss: 1.2112, Validation Accuracy: 59.49%
# Epoch 30/100, Train Loss: 1.2771, Train Accuracy: 57.03%, Validation Loss: 1.2107, Validation Accuracy: 59.30%
# Epoch 31/100, Train Loss: 1.2701, Train Accuracy: 57.34%, Validation Loss: 1.2044, Validation Accuracy: 59.64%
# Epoch 32/100, Train Loss: 1.2637, Train Accuracy: 57.47%, Validation Loss: 1.1995, Validation Accuracy: 59.60%
# Epoch 33/100, Train Loss: 1.2587, Train Accuracy: 57.64%, Validation Loss: 1.1910, Validation Accuracy: 60.00%
# Epoch 34/100, Train Loss: 1.2522, Train Accuracy: 57.85%, Validation Loss: 1.1876, Validation Accuracy: 60.14%
# Epoch 35/100, Train Loss: 1.2465, Train Accuracy: 57.92%, Validation Loss: 1.1828, Validation Accuracy: 60.40%
# Epoch 36/100, Train Loss: 1.2419, Train Accuracy: 58.28%, Validation Loss: 1.1752, Validation Accuracy: 60.46%
# Epoch 37/100, Train Loss: 1.2365, Train Accuracy: 58.41%, Validation Loss: 1.1726, Validation Accuracy: 60.61%
# Epoch 38/100, Train Loss: 1.2305, Train Accuracy: 58.46%, Validation Loss: 1.1654, Validation Accuracy: 60.76%
# Epoch 39/100, Train Loss: 1.2295, Train Accuracy: 58.55%, Validation Loss: 1.1620, Validation Accuracy: 60.85%
# Epoch 40/100, Train Loss: 1.2225, Train Accuracy: 58.81%, Validation Loss: 1.1573, Validation Accuracy: 61.20%
# Epoch 41/100, Train Loss: 1.2152, Train Accuracy: 59.03%, Validation Loss: 1.1552, Validation Accuracy: 61.15%
# Epoch 42/100, Train Loss: 1.2128, Train Accuracy: 59.14%, Validation Loss: 1.1494, Validation Accuracy: 61.38%
# Epoch 43/100, Train Loss: 1.2103, Train Accuracy: 59.17%, Validation Loss: 1.1472, Validation Accuracy: 61.34%
# Epoch 44/100, Train Loss: 1.2028, Train Accuracy: 59.40%, Validation Loss: 1.1432, Validation Accuracy: 61.61%
# Epoch 45/100, Train Loss: 1.1983, Train Accuracy: 59.64%, Validation Loss: 1.1431, Validation Accuracy: 61.70%
# Epoch 46/100, Train Loss: 1.1949, Train Accuracy: 59.63%, Validation Loss: 1.1377, Validation Accuracy: 61.65%
# Epoch 47/100, Train Loss: 1.1934, Train Accuracy: 59.63%, Validation Loss: 1.1324, Validation Accuracy: 61.73%
# Epoch 48/100, Train Loss: 1.1902, Train Accuracy: 59.91%, Validation Loss: 1.1321, Validation Accuracy: 61.95%
# Epoch 49/100, Train Loss: 1.1871, Train Accuracy: 60.02%, Validation Loss: 1.1317, Validation Accuracy: 62.12%
# Epoch 50/100, Train Loss: 1.1823, Train Accuracy: 60.21%, Validation Loss: 1.1284, Validation Accuracy: 62.02%
# Epoch 51/100, Train Loss: 1.1780, Train Accuracy: 60.08%, Validation Loss: 1.1241, Validation Accuracy: 61.95%
# Epoch 52/100, Train Loss: 1.1736, Train Accuracy: 60.37%, Validation Loss: 1.1238, Validation Accuracy: 62.11%
# Epoch 53/100, Train Loss: 1.1732, Train Accuracy: 60.38%, Validation Loss: 1.1216, Validation Accuracy: 62.55%
# Epoch 54/100, Train Loss: 1.1650, Train Accuracy: 60.66%, Validation Loss: 1.1153, Validation Accuracy: 62.54%
# Epoch 55/100, Train Loss: 1.1653, Train Accuracy: 60.78%, Validation Loss: 1.1116, Validation Accuracy: 62.32%
# Epoch 56/100, Train Loss: 1.1610, Train Accuracy: 60.88%, Validation Loss: 1.1117, Validation Accuracy: 62.77%
# Epoch 57/100, Train Loss: 1.1607, Train Accuracy: 60.75%, Validation Loss: 1.1057, Validation Accuracy: 62.76%
# Epoch 58/100, Train Loss: 1.1553, Train Accuracy: 61.00%, Validation Loss: 1.1031, Validation Accuracy: 63.02%
# Epoch 59/100, Train Loss: 1.1526, Train Accuracy: 61.12%, Validation Loss: 1.1011, Validation Accuracy: 62.81%
# Epoch 60/100, Train Loss: 1.1491, Train Accuracy: 61.09%, Validation Loss: 1.1045, Validation Accuracy: 62.75%
# Epoch 61/100, Train Loss: 1.1469, Train Accuracy: 61.31%, Validation Loss: 1.0966, Validation Accuracy: 63.11%
# Epoch 62/100, Train Loss: 1.1458, Train Accuracy: 61.22%, Validation Loss: 1.0943, Validation Accuracy: 63.24%
# Epoch 63/100, Train Loss: 1.1419, Train Accuracy: 61.49%, Validation Loss: 1.0922, Validation Accuracy: 63.18%
# Epoch 64/100, Train Loss: 1.1422, Train Accuracy: 61.39%, Validation Loss: 1.0879, Validation Accuracy: 63.33%
# Epoch 65/100, Train Loss: 1.1354, Train Accuracy: 61.55%, Validation Loss: 1.0871, Validation Accuracy: 63.51%
# Epoch 66/100, Train Loss: 1.1352, Train Accuracy: 61.62%, Validation Loss: 1.0851, Validation Accuracy: 63.29%
# Epoch 67/100, Train Loss: 1.1296, Train Accuracy: 61.89%, Validation Loss: 1.0850, Validation Accuracy: 63.40%
# Epoch 68/100, Train Loss: 1.1282, Train Accuracy: 61.86%, Validation Loss: 1.0811, Validation Accuracy: 63.63%
# Epoch 69/100, Train Loss: 1.1269, Train Accuracy: 61.94%, Validation Loss: 1.0790, Validation Accuracy: 63.64%
# Epoch 70/100, Train Loss: 1.1243, Train Accuracy: 62.10%, Validation Loss: 1.0791, Validation Accuracy: 63.60%
# Epoch 71/100, Train Loss: 1.1211, Train Accuracy: 62.09%, Validation Loss: 1.0764, Validation Accuracy: 63.85%
# Epoch 72/100, Train Loss: 1.1216, Train Accuracy: 62.18%, Validation Loss: 1.0763, Validation Accuracy: 63.53%
# Epoch 73/100, Train Loss: 1.1182, Train Accuracy: 62.27%, Validation Loss: 1.0741, Validation Accuracy: 63.85%
# Epoch 74/100, Train Loss: 1.1143, Train Accuracy: 62.32%, Validation Loss: 1.0684, Validation Accuracy: 64.09%
# Epoch 75/100, Train Loss: 1.1141, Train Accuracy: 62.30%, Validation Loss: 1.0728, Validation Accuracy: 63.89%
# Epoch 76/100, Train Loss: 1.1127, Train Accuracy: 62.51%, Validation Loss: 1.0655, Validation Accuracy: 64.15%
# Epoch 77/100, Train Loss: 1.1085, Train Accuracy: 62.59%, Validation Loss: 1.0654, Validation Accuracy: 64.03%
# Epoch 78/100, Train Loss: 1.1048, Train Accuracy: 62.60%, Validation Loss: 1.0672, Validation Accuracy: 64.36%
# Epoch 79/100, Train Loss: 1.1041, Train Accuracy: 62.61%, Validation Loss: 1.0647, Validation Accuracy: 64.10%
# Epoch 80/100, Train Loss: 1.1034, Train Accuracy: 62.74%, Validation Loss: 1.0619, Validation Accuracy: 64.22%
# Epoch 81/100, Train Loss: 1.0980, Train Accuracy: 62.84%, Validation Loss: 1.0618, Validation Accuracy: 64.67%
# Epoch 82/100, Train Loss: 1.0998, Train Accuracy: 62.80%, Validation Loss: 1.0580, Validation Accuracy: 64.46%
# Epoch 83/100, Train Loss: 1.0990, Train Accuracy: 62.91%, Validation Loss: 1.0586, Validation Accuracy: 64.17%
# Epoch 84/100, Train Loss: 1.0961, Train Accuracy: 63.02%, Validation Loss: 1.0580, Validation Accuracy: 64.50%
# Epoch 85/100, Train Loss: 1.0929, Train Accuracy: 62.98%, Validation Loss: 1.0508, Validation Accuracy: 64.53%
# Epoch 86/100, Train Loss: 1.0939, Train Accuracy: 63.01%, Validation Loss: 1.0554, Validation Accuracy: 64.76%
# Epoch 87/100, Train Loss: 1.0914, Train Accuracy: 63.15%, Validation Loss: 1.0535, Validation Accuracy: 64.55%
# Epoch 88/100, Train Loss: 1.0891, Train Accuracy: 63.28%, Validation Loss: 1.0509, Validation Accuracy: 64.82%
# Epoch 89/100, Train Loss: 1.0892, Train Accuracy: 63.17%, Validation Loss: 1.0497, Validation Accuracy: 64.52%
# Epoch 90/100, Train Loss: 1.0856, Train Accuracy: 63.30%, Validation Loss: 1.0487, Validation Accuracy: 64.59%
# Epoch 91/100, Train Loss: 1.0837, Train Accuracy: 63.40%, Validation Loss: 1.0475, Validation Accuracy: 64.74%
# Epoch 92/100, Train Loss: 1.0829, Train Accuracy: 63.38%, Validation Loss: 1.0496, Validation Accuracy: 64.64%
# Epoch 93/100, Train Loss: 1.0823, Train Accuracy: 63.41%, Validation Loss: 1.0458, Validation Accuracy: 65.09%
# Epoch 94/100, Train Loss: 1.0796, Train Accuracy: 63.55%, Validation Loss: 1.0440, Validation Accuracy: 64.78%
# Epoch 95/100, Train Loss: 1.0771, Train Accuracy: 63.56%, Validation Loss: 1.0461, Validation Accuracy: 65.12%
# Epoch 96/100, Train Loss: 1.0753, Train Accuracy: 63.67%, Validation Loss: 1.0429, Validation Accuracy: 65.00%
# Epoch 97/100, Train Loss: 1.0736, Train Accuracy: 63.63%, Validation Loss: 1.0404, Validation Accuracy: 65.06%
# Epoch 98/100, Train Loss: 1.0754, Train Accuracy: 63.62%, Validation Loss: 1.0412, Validation Accuracy: 65.07%
# Epoch 99/100, Train Loss: 1.0708, Train Accuracy: 63.70%, Validation Loss: 1.0391, Validation Accuracy: 64.81%
# Epoch 100/100, Train Loss: 1.0702, Train Accuracy: 63.76%, Validation Loss: 1.0425, Validation Accuracy: 65.00%

# %%
model_save_path = "GUI/models/app_classification_resnet50.pth"
torch.save({
    'model_state_dict': resnet50.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_list': train_loss_list,
    'validate_loss_list': validate_loss_list,
    'train_accuracy_list': train_accuracy_list,
    'validate_accuracy_list': validate_accuracy_list
}, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to GUI/models/app_classification_resnet50.pth

# %%
model_save_path = "GUI/models/app_classification_resnet50.pth"
resnet50 = models.resnet50(pretrained=True)
# Fine tuning
for param in resnet50.parameters():
    param.requires_grad = False
num_classes = 14
fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes), 
    nn.LogSoftmax(dim=1)
)

checkpoint = torch.load(model_save_path)
resnet50.load_state_dict(checkpoint['model_state_dict'])

train_loss_list = checkpoint['train_loss_list']
validate_loss_list = checkpoint['validate_loss_list']
train_accuracy_list = checkpoint['train_accuracy_list']
validate_accuracy_list = checkpoint['validate_accuracy_list']

# %%
resnet50 = resnet50.to(device)
resnet50.eval()
correct_predictions = 0
total_predictions = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
            
        outputs = resnet50(inputs)
            
        _, predicted = torch.max(outputs, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    
    predict_accuracy = correct_predictions / total_predictions
    
    print(predict_accuracy)
# Out:
# 0.6940195531546344

# %%
epochs = range(1, len(train_accuracy_list) + 1)
# Độ chính xác trên tập huấn luyện và tập validate
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_accuracy_list, 'b', label='Train Accuracy')
plt.plot(epochs, validate_accuracy_list, 'r', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss_list, 'b', label='Train Loss')
plt.plot(epochs, validate_loss_list, 'r', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Tính confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# In ra confusion matrix
class_names = [str(i) for i in range(len(cm))]
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="g",
            xticklabels=class_names, yticklabels=class_names)

for i in range(len(class_names)):
    plt.text(i + 0.5, i + 0.5, cm[i, i], ha="center",
             va="center", color="black")

print("ResNet50's Confusion Matrix:")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ResNet50's Confusion Matrix:

# %%
# Tính Precision, Recall, và F1-Score cho từng lớp
precisions = precision_score(all_labels, all_predictions, average=None)
recalls = recall_score(all_labels, all_predictions, average=None)
f1_scores = f1_score(all_labels, all_predictions, average=None)

resnet50_precision = np.mean(precisions)
resnet50_recall = np.mean(recalls)
resent50_f1_score = np.mean(f1_scores)
resnet50_acc = predict_accuracy

print("ResNet50's precision", resnet50_precision)
print("ResNet50's recall", resnet50_recall)
print("ResNet50's f1-score",resent50_f1_score)
print(f"ResNet50's Accuracy: {resnet50_acc}")
# Out:
# ResNet50's precision 0.6959574429949802
# ResNet50's recall 0.6930936338832859
# ResNet50's f1-score 0.6899100887632159
# ResNet50's Accuracy: 0.6940195531546344

# %% [markdown]
# AlexNet

# %%
alexnet = models.alexnet(pretrained=True)
# Fine tuning
for param in alexnet.features.parameters():
    param.requires_grad = False

in_features = alexnet.classifier[6].in_features
num_classes = 14
alexnet.classifier[6] = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

# %%
learning_rate = 0.0001
num_epochs = 100
weight_decay = 0.001

# %%
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(
        alexnet.classifier.parameters(), lr=learning_rate, weight_decay=weight_decay)

# %%
# Các giá trị cần lưu để đánh giá model
train_loss_list = []
train_accuracy_list = []
validate_loss_list = []  # Để lưu loss trên tập validate
validate_accuracy_list = []  # Để lưu accuracy trên tập validate

best_loss = float('inf')  # Giá trị loss tốt nhất
patience = 5  # Số epoch không giảm loss hoặc không tăng accuracy cho phép trước khi dừng
no_improvement_count = 0  # Đếm số epoch không cải thiện

# %%
alexnet.to(device)
for epoch in range(num_epochs):
    alexnet.train()
    total_train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = alexnet(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = correct_train / total_train
    average_train_loss = total_train_loss / len(train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(average_train_loss)

    # Validation
    alexnet.eval()
    total_validation_loss = 0.0
    correct_validation = 0
    total_validation = 0
    
    with torch.no_grad():
        for inputs, labels in validate_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = alexnet(inputs)
            loss = criterion(outputs, labels)
            
            total_validation_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
    
    validation_accuracy = correct_validation / total_validation
    average_validation_loss = total_validation_loss / len(validate_loader)
    validate_accuracy_list.append(validation_accuracy)
    validate_loss_list.append(average_validation_loss)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {average_train_loss:.4f}, Train Accuracy: {100 * train_accuracy:.2f}%, Validation Loss: {average_validation_loss:.4f}, Validation Accuracy: {100 * validation_accuracy:.2f}%')


    if validate_loss_list[-1] >= best_loss:
        no_improvement_count += 1
    else:
        best_loss = validate_loss_list[-1]
        no_improvement_count = 0
        # Nếu không cải thiện trong số lần đã định, dừng huấn luyện
    if no_improvement_count >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        break
# Out:
# Epoch 1/100, Train Loss: 1.9215, Train Accuracy: 35.50%, Validation Loss: 1.5075, Validation Accuracy: 49.02%
# Epoch 2/100, Train Loss: 1.6203, Train Accuracy: 45.22%, Validation Loss: 1.3597, Validation Accuracy: 53.00%
# Epoch 3/100, Train Loss: 1.5087, Train Accuracy: 48.61%, Validation Loss: 1.2696, Validation Accuracy: 56.12%
# Epoch 4/100, Train Loss: 1.4326, Train Accuracy: 51.09%, Validation Loss: 1.2191, Validation Accuracy: 58.07%
# Epoch 5/100, Train Loss: 1.3765, Train Accuracy: 52.96%, Validation Loss: 1.1773, Validation Accuracy: 59.15%
# Epoch 6/100, Train Loss: 1.3347, Train Accuracy: 54.37%, Validation Loss: 1.1329, Validation Accuracy: 60.73%
# Epoch 7/100, Train Loss: 1.2946, Train Accuracy: 55.50%, Validation Loss: 1.0929, Validation Accuracy: 61.69%
# Epoch 8/100, Train Loss: 1.2606, Train Accuracy: 56.54%, Validation Loss: 1.0743, Validation Accuracy: 62.40%
# Epoch 9/100, Train Loss: 1.2317, Train Accuracy: 57.53%, Validation Loss: 1.0435, Validation Accuracy: 63.40%
# Epoch 10/100, Train Loss: 1.2046, Train Accuracy: 58.39%, Validation Loss: 1.0243, Validation Accuracy: 64.03%
# Epoch 11/100, Train Loss: 1.1801, Train Accuracy: 59.14%, Validation Loss: 0.9970, Validation Accuracy: 65.18%
# Epoch 12/100, Train Loss: 1.1587, Train Accuracy: 60.06%, Validation Loss: 0.9718, Validation Accuracy: 66.27%
# Epoch 13/100, Train Loss: 1.1417, Train Accuracy: 60.45%, Validation Loss: 0.9554, Validation Accuracy: 66.68%
# Epoch 14/100, Train Loss: 1.1209, Train Accuracy: 61.22%, Validation Loss: 0.9378, Validation Accuracy: 67.44%
# Epoch 15/100, Train Loss: 1.1024, Train Accuracy: 61.74%, Validation Loss: 0.9216, Validation Accuracy: 67.77%
# Epoch 16/100, Train Loss: 1.0833, Train Accuracy: 62.40%, Validation Loss: 0.9104, Validation Accuracy: 68.08%
# Epoch 17/100, Train Loss: 1.0704, Train Accuracy: 62.92%, Validation Loss: 0.8928, Validation Accuracy: 68.52%
# Epoch 18/100, Train Loss: 1.0599, Train Accuracy: 63.19%, Validation Loss: 0.8917, Validation Accuracy: 68.83%
# Epoch 19/100, Train Loss: 1.0391, Train Accuracy: 63.91%, Validation Loss: 0.8715, Validation Accuracy: 69.30%
# Epoch 20/100, Train Loss: 1.0278, Train Accuracy: 64.38%, Validation Loss: 0.8534, Validation Accuracy: 69.92%
# Epoch 21/100, Train Loss: 1.0181, Train Accuracy: 64.76%, Validation Loss: 0.8400, Validation Accuracy: 70.64%
# Epoch 22/100, Train Loss: 1.0083, Train Accuracy: 65.10%, Validation Loss: 0.8243, Validation Accuracy: 70.87%
# Epoch 23/100, Train Loss: 0.9944, Train Accuracy: 65.58%, Validation Loss: 0.8208, Validation Accuracy: 71.17%
# Epoch 24/100, Train Loss: 0.9844, Train Accuracy: 65.86%, Validation Loss: 0.8108, Validation Accuracy: 71.44%
# Epoch 25/100, Train Loss: 0.9737, Train Accuracy: 66.18%, Validation Loss: 0.8105, Validation Accuracy: 71.74%
# Epoch 26/100, Train Loss: 0.9659, Train Accuracy: 66.48%, Validation Loss: 0.7912, Validation Accuracy: 72.48%
# Epoch 27/100, Train Loss: 0.9577, Train Accuracy: 66.79%, Validation Loss: 0.7942, Validation Accuracy: 72.01%
# Epoch 28/100, Train Loss: 0.9471, Train Accuracy: 67.08%, Validation Loss: 0.7753, Validation Accuracy: 72.91%
# Epoch 29/100, Train Loss: 0.9410, Train Accuracy: 67.30%, Validation Loss: 0.7813, Validation Accuracy: 72.47%
# Epoch 30/100, Train Loss: 0.9305, Train Accuracy: 67.64%, Validation Loss: 0.7630, Validation Accuracy: 73.37%
# Epoch 31/100, Train Loss: 0.9265, Train Accuracy: 67.81%, Validation Loss: 0.7565, Validation Accuracy: 73.55%
# Epoch 32/100, Train Loss: 0.9155, Train Accuracy: 68.10%, Validation Loss: 0.7495, Validation Accuracy: 73.74%
# Epoch 33/100, Train Loss: 0.9048, Train Accuracy: 68.36%, Validation Loss: 0.7499, Validation Accuracy: 74.05%
# Epoch 34/100, Train Loss: 0.9048, Train Accuracy: 68.58%, Validation Loss: 0.7352, Validation Accuracy: 74.43%
# Epoch 35/100, Train Loss: 0.8957, Train Accuracy: 68.81%, Validation Loss: 0.7375, Validation Accuracy: 73.84%
# Epoch 36/100, Train Loss: 0.8903, Train Accuracy: 69.00%, Validation Loss: 0.7312, Validation Accuracy: 74.61%
# Epoch 37/100, Train Loss: 0.8820, Train Accuracy: 69.23%, Validation Loss: 0.7279, Validation Accuracy: 74.59%
# Epoch 38/100, Train Loss: 0.8802, Train Accuracy: 69.35%, Validation Loss: 0.7112, Validation Accuracy: 74.93%
# Epoch 39/100, Train Loss: 0.8728, Train Accuracy: 69.61%, Validation Loss: 0.7090, Validation Accuracy: 74.82%
# Epoch 40/100, Train Loss: 0.8670, Train Accuracy: 69.75%, Validation Loss: 0.7122, Validation Accuracy: 74.98%
# Epoch 41/100, Train Loss: 0.8602, Train Accuracy: 70.14%, Validation Loss: 0.6964, Validation Accuracy: 75.68%
# Epoch 42/100, Train Loss: 0.8565, Train Accuracy: 70.12%, Validation Loss: 0.7023, Validation Accuracy: 75.43%
# Epoch 43/100, Train Loss: 0.8492, Train Accuracy: 70.44%, Validation Loss: 0.7017, Validation Accuracy: 75.17%
# Epoch 44/100, Train Loss: 0.8457, Train Accuracy: 70.47%, Validation Loss: 0.6997, Validation Accuracy: 75.42%
# Epoch 45/100, Train Loss: 0.8423, Train Accuracy: 70.64%, Validation Loss: 0.6850, Validation Accuracy: 76.05%
# Epoch 46/100, Train Loss: 0.8377, Train Accuracy: 70.68%, Validation Loss: 0.6780, Validation Accuracy: 75.95%
# Epoch 47/100, Train Loss: 0.8326, Train Accuracy: 71.00%, Validation Loss: 0.6886, Validation Accuracy: 75.75%
# Epoch 48/100, Train Loss: 0.8267, Train Accuracy: 71.11%, Validation Loss: 0.6768, Validation Accuracy: 76.24%
# Epoch 49/100, Train Loss: 0.8237, Train Accuracy: 71.26%, Validation Loss: 0.6814, Validation Accuracy: 75.90%
# Epoch 50/100, Train Loss: 0.8184, Train Accuracy: 71.33%, Validation Loss: 0.6775, Validation Accuracy: 76.24%
# Epoch 51/100, Train Loss: 0.8169, Train Accuracy: 71.61%, Validation Loss: 0.6669, Validation Accuracy: 76.52%
# Epoch 52/100, Train Loss: 0.8126, Train Accuracy: 71.69%, Validation Loss: 0.6694, Validation Accuracy: 76.52%
# Epoch 53/100, Train Loss: 0.8116, Train Accuracy: 71.58%, Validation Loss: 0.6662, Validation Accuracy: 76.32%
# Epoch 54/100, Train Loss: 0.8070, Train Accuracy: 71.80%, Validation Loss: 0.6653, Validation Accuracy: 76.46%
# Epoch 55/100, Train Loss: 0.8010, Train Accuracy: 71.94%, Validation Loss: 0.6605, Validation Accuracy: 76.76%
# Epoch 56/100, Train Loss: 0.8014, Train Accuracy: 71.98%, Validation Loss: 0.6597, Validation Accuracy: 76.86%
# Epoch 57/100, Train Loss: 0.7958, Train Accuracy: 72.25%, Validation Loss: 0.6474, Validation Accuracy: 76.74%
# Epoch 58/100, Train Loss: 0.7934, Train Accuracy: 72.19%, Validation Loss: 0.6438, Validation Accuracy: 77.45%
# Epoch 59/100, Train Loss: 0.7893, Train Accuracy: 72.36%, Validation Loss: 0.6518, Validation Accuracy: 76.88%
# Epoch 60/100, Train Loss: 0.7883, Train Accuracy: 72.44%, Validation Loss: 0.6444, Validation Accuracy: 77.45%
# Epoch 61/100, Train Loss: 0.7879, Train Accuracy: 72.31%, Validation Loss: 0.6466, Validation Accuracy: 77.26%
# Epoch 62/100, Train Loss: 0.7816, Train Accuracy: 72.63%, Validation Loss: 0.6472, Validation Accuracy: 77.49%
# Epoch 63/100, Train Loss: 0.7798, Train Accuracy: 72.75%, Validation Loss: 0.6453, Validation Accuracy: 76.81%
# Early stopping at epoch 63

# %%
model_save_path = "GUI/models/app_classification_alexnet.pth"
torch.save({
    'model_state_dict': alexnet.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_list': train_loss_list,
    'validate_loss_list': validate_loss_list,
    'train_accuracy_list': train_accuracy_list,
    'validate_accuracy_list': validate_accuracy_list
}, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to GUI/models/app_classification_alexnet.pth

# %%
model_save_path = "GUI/models/app_classification_alexnet.pth"
alexnet = models.alexnet(pretrained=True)
# Fine tuning
for param in alexnet.features.parameters():
    param.requires_grad = False

in_features = alexnet.classifier[6].in_features
num_classes = 14
alexnet.classifier[6] = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

checkpoint = torch.load(model_save_path)
alexnet.load_state_dict(checkpoint['model_state_dict'])

train_loss_list = checkpoint['train_loss_list']
validate_loss_list = checkpoint['validate_loss_list']
train_accuracy_list = checkpoint['train_accuracy_list']
validate_accuracy_list = checkpoint['validate_accuracy_list']

# %%
alexnet = alexnet.to(device)
alexnet.eval()
correct_predictions = 0
total_predictions = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
            
        outputs = alexnet(inputs)
            
        _, predicted = torch.max(outputs, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    
    predict_accuracy = correct_predictions / total_predictions
    
    print(predict_accuracy)
# Out:
# 0.7971286808960395

# %%
epochs = range(1, len(train_accuracy_list) + 1)
# Độ chính xác trên tập huấn luyện và tập validate
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_accuracy_list, 'b', label='Train Accuracy')
plt.plot(epochs, validate_accuracy_list, 'r', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss_list, 'b', label='Train Loss')
plt.plot(epochs, validate_loss_list, 'r', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Tính confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# In ra confusion matrix
class_names = [str(i) for i in range(len(cm))]
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="g",
            xticklabels=class_names, yticklabels=class_names)

for i in range(len(class_names)):
    plt.text(i + 0.5, i + 0.5, cm[i, i], ha="center",
             va="center", color="black")

print("AlexNet's Confusion Matrix:")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AlexNet's Confusion Matrix:

# %%
# Tính Precision, Recall, và F1-Score cho từng lớp
precisions = precision_score(all_labels, all_predictions, average=None)
recalls = recall_score(all_labels, all_predictions, average=None)
f1_scores = f1_score(all_labels, all_predictions, average=None)

alexnet_precision = np.mean(precisions)
alexnet_recall = np.mean(recalls)
alexnet_f1_score = np.mean(f1_scores)
alexnet_acc = predict_accuracy

print("AlexNet's precision", alexnet_precision)
print("AlexNet's recall", alexnet_recall)
print("AlexNet's f1-score",alexnet_f1_score)
print(f"AlexNet's Accuracy: {alexnet_acc}")
# Out:
# AlexNet's precision 0.8014933834564468
# AlexNet's recall 0.7970972721548358
# AlexNet's f1-score 0.794722365354339
# AlexNet's Accuracy: 0.7971286808960395

# %% [markdown]
# VGG-16

# %%
vgg16 = models.vgg16(pretrained=True)

for param in vgg16.features.parameters():
    param.requires_grad = False

in_features = vgg16.classifier[-1].in_features
num_classes = 14
vgg16.classifier[-1] = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

# %%
learning_rate = 0.0001
num_epochs = 20 # Mô hình VGG quá lớn để train nhiều epochs
weight_decay = 0.001

# %%
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(
        vgg16.classifier.parameters(), lr=learning_rate, weight_decay=weight_decay)

# %%
# Các giá trị cần lưu để đánh giá model
train_loss_list = []
train_accuracy_list = []
validate_loss_list = []  # Để lưu loss trên tập validate
validate_accuracy_list = []  # Để lưu accuracy trên tập validate

best_loss = float('inf')  # Giá trị loss tốt nhất
patience = 5  # Số epoch không giảm loss hoặc không tăng accuracy cho phép trước khi dừng
no_improvement_count = 0  # Đếm số epoch không cải thiện

# %%
vgg16.to(device)
for epoch in range(num_epochs):
    vgg16.train()
    total_train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = vgg16(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = correct_train / total_train
    average_train_loss = total_train_loss / len(train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(average_train_loss)

    # Validation
    vgg16.eval()
    total_validation_loss = 0.0
    correct_validation = 0
    total_validation = 0
    
    with torch.no_grad():
        for inputs, labels in validate_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = vgg16(inputs)
            loss = criterion(outputs, labels)
            
            total_validation_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
    
    validation_accuracy = correct_validation / total_validation
    average_validation_loss = total_validation_loss / len(validate_loader)
    validate_accuracy_list.append(validation_accuracy)
    validate_loss_list.append(average_validation_loss)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {average_train_loss:.4f}, Train Accuracy: {100 * train_accuracy:.2f}%, Validation Loss: {average_validation_loss:.4f}, Validation Accuracy: {100 * validation_accuracy:.2f}%')

    if validate_loss_list[-1] >= best_loss:
        no_improvement_count += 1
    else:
        best_loss = validate_loss_list[-1]
        no_improvement_count = 0
        # Nếu không cải thiện trong số lần đã định, dừng huấn luyện
    if no_improvement_count >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        break
# Out:
# Epoch 1/20, Train Loss: 1.8078, Train Accuracy: 39.40%, Validation Loss: 1.4044, Validation Accuracy: 51.79%
# Epoch 2/20, Train Loss: 1.4042, Train Accuracy: 52.42%, Validation Loss: 1.1763, Validation Accuracy: 58.41%
# Epoch 3/20, Train Loss: 1.2415, Train Accuracy: 57.49%, Validation Loss: 1.0736, Validation Accuracy: 62.85%
# Epoch 4/20, Train Loss: 1.1519, Train Accuracy: 60.54%, Validation Loss: 0.9721, Validation Accuracy: 66.02%
# Epoch 5/20, Train Loss: 1.0852, Train Accuracy: 62.85%, Validation Loss: 0.9379, Validation Accuracy: 67.16%
# Epoch 6/20, Train Loss: 1.0409, Train Accuracy: 64.30%, Validation Loss: 0.8891, Validation Accuracy: 68.82%
# Epoch 7/20, Train Loss: 1.0050, Train Accuracy: 65.55%, Validation Loss: 0.8516, Validation Accuracy: 69.69%
# Epoch 8/20, Train Loss: 0.9769, Train Accuracy: 66.45%, Validation Loss: 0.8467, Validation Accuracy: 70.23%
# Epoch 9/20, Train Loss: 0.9503, Train Accuracy: 67.49%, Validation Loss: 0.8289, Validation Accuracy: 70.38%
# Epoch 10/20, Train Loss: 0.9296, Train Accuracy: 67.94%, Validation Loss: 0.8087, Validation Accuracy: 71.48%
# Epoch 11/20, Train Loss: 0.9068, Train Accuracy: 68.83%, Validation Loss: 0.7830, Validation Accuracy: 72.56%
# Epoch 12/20, Train Loss: 0.8974, Train Accuracy: 69.12%, Validation Loss: 0.7730, Validation Accuracy: 72.35%
# Epoch 13/20, Train Loss: 0.8772, Train Accuracy: 69.80%, Validation Loss: 0.7564, Validation Accuracy: 73.04%
# Epoch 14/20, Train Loss: 0.8720, Train Accuracy: 69.95%, Validation Loss: 0.7464, Validation Accuracy: 73.66%
# Epoch 15/20, Train Loss: 0.8567, Train Accuracy: 70.38%, Validation Loss: 0.7370, Validation Accuracy: 74.24%
# Epoch 16/20, Train Loss: 0.8450, Train Accuracy: 70.92%, Validation Loss: 0.7216, Validation Accuracy: 74.58%
# Epoch 17/20, Train Loss: 0.8393, Train Accuracy: 70.98%, Validation Loss: 0.7134, Validation Accuracy: 74.47%
# Epoch 18/20, Train Loss: 0.8245, Train Accuracy: 71.51%, Validation Loss: 0.7003, Validation Accuracy: 75.46%
# Epoch 19/20, Train Loss: 0.8263, Train Accuracy: 71.47%, Validation Loss: 0.7136, Validation Accuracy: 74.86%
# Epoch 20/20, Train Loss: 0.8120, Train Accuracy: 72.04%, Validation Loss: 0.7056, Validation Accuracy: 75.04%

# %%
model_save_path = "GUI/models/app_classification_vgg16.pth"
torch.save({
    'model_state_dict': vgg16.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_list': train_loss_list,
    'validate_loss_list': validate_loss_list,
    'train_accuracy_list': train_accuracy_list,
    'validate_accuracy_list': validate_accuracy_list
}, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to GUI/models/app_classification_vgg16.pth

# %%
model_save_path = "GUI/models/app_classification_vgg16.pth"
vgg16 = models.vgg16(pretrained=True)

for param in vgg16.features.parameters():
    param.requires_grad = False

in_features = vgg16.classifier[-1].in_features
num_classes = 14
vgg16.classifier[-1] = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

checkpoint = torch.load(model_save_path)
vgg16.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

train_loss_list = checkpoint['train_loss_list']
validate_loss_list = checkpoint['validate_loss_list']
train_accuracy_list = checkpoint['train_accuracy_list']
validate_accuracy_list = checkpoint['validate_accuracy_list']

# %% [markdown]
# Train tiếp cho VGG-16

# %%
more_epoch = 50
last_epoch = len(train_loss_list)
end_epoch = last_epoch + more_epoch
patience = 5

print("Last epoch: ", last_epoch)
print("End epoch: ", end_epoch)
# Out:
# Last epoch:  20
# End epoch:  70

# %%
vgg16.to(device)
criterion = nn.CrossEntropyLoss().to(device)
for epoch in range(last_epoch, end_epoch):
    vgg16.train()
    total_train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = vgg16(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = correct_train / total_train
    average_train_loss = total_train_loss / len(train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(average_train_loss)

    # Validation
    vgg16.eval()
    total_validation_loss = 0.0
    correct_validation = 0
    total_validation = 0
    
    with torch.no_grad():
        for inputs, labels in validate_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = vgg16(inputs)
            loss = criterion(outputs, labels)
            
            total_validation_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
    
    validation_accuracy = correct_validation / total_validation
    average_validation_loss = total_validation_loss / len(validate_loader)
    validate_accuracy_list.append(validation_accuracy)
    validate_loss_list.append(average_validation_loss)
    
    print(f'Epoch {epoch+1}/{end_epoch}, Train Loss: {average_train_loss:.4f}, Train Accuracy: {100 * train_accuracy:.2f}%, Validation Loss: {average_validation_loss:.4f}, Validation Accuracy: {100 * validation_accuracy:.2f}%')

    if validate_loss_list[-1] >= best_loss:
        no_improvement_count += 1
    else:
        best_loss = validate_loss_list[-1]
        no_improvement_count = 0
        # Nếu không cải thiện trong số lần đã định, dừng huấn luyện
    if no_improvement_count >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        break
# Out:
# Epoch 21/70, Train Loss: 0.8278, Train Accuracy: 71.38%, Validation Loss: 0.6630, Validation Accuracy: 76.82%
# Epoch 22/70, Train Loss: 0.8255, Train Accuracy: 71.51%, Validation Loss: 0.6634, Validation Accuracy: 76.82%
# Epoch 23/70, Train Loss: 0.8282, Train Accuracy: 71.38%, Validation Loss: 0.6634, Validation Accuracy: 76.82%
# Epoch 24/70, Train Loss: 0.8274, Train Accuracy: 71.47%, Validation Loss: 0.6632, Validation Accuracy: 76.82%
# Epoch 25/70, Train Loss: 0.8268, Train Accuracy: 71.45%, Validation Loss: 0.6637, Validation Accuracy: 76.82%
# Epoch 26/70, Train Loss: 0.8252, Train Accuracy: 71.55%, Validation Loss: 0.6631, Validation Accuracy: 76.82%
# Early stopping at epoch 26

# %%
model_save_path = "GUI/models/app_classification_vgg16.pth"
torch.save({
    'model_state_dict': vgg16.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_list': train_loss_list,
    'validate_loss_list': validate_loss_list,
    'train_accuracy_list': train_accuracy_list,
    'validate_accuracy_list': validate_accuracy_list
}, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to GUI/models/app_classification_vgg16.pth

# %%
model_save_path = "GUI/models/app_classification_vgg16.pth"
vgg16 = models.vgg16(pretrained=True)

for param in vgg16.features.parameters():
    param.requires_grad = False

in_features = vgg16.classifier[-1].in_features
num_classes = 14
vgg16.classifier[-1] = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

checkpoint = torch.load(model_save_path)
vgg16.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

train_loss_list = checkpoint['train_loss_list']
validate_loss_list = checkpoint['validate_loss_list']
train_accuracy_list = checkpoint['train_accuracy_list']
validate_accuracy_list = checkpoint['validate_accuracy_list']

# %%
vgg16 = vgg16.to(device)
vgg16.eval()
correct_predictions = 0
total_predictions = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
            
        outputs = vgg16(inputs)
            
        _, predicted = torch.max(outputs, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    
    predict_accuracy = correct_predictions / total_predictions
    
    print(predict_accuracy)
# Out:
# 0.7681218989460087

# %%
epochs = range(1, len(train_accuracy_list) + 1)
# Độ chính xác trên tập huấn luyện và tập validate
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_accuracy_list, 'b', label='Train Accuracy')
plt.plot(epochs, validate_accuracy_list, 'r', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss_list, 'b', label='Train Loss')
plt.plot(epochs, validate_loss_list, 'r', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Tính confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# In ra confusion matrix
class_names = [str(i) for i in range(len(cm))]
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="g",
            xticklabels=class_names, yticklabels=class_names)

for i in range(len(class_names)):
    plt.text(i + 0.5, i + 0.5, cm[i, i], ha="center",
             va="center", color="black")

print("VGG-16's Confusion Matrix:")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# VGG-16's Confusion Matrix:

# %%
# Tính Precision, Recall, và F1-Score cho từng lớp
precisions = precision_score(all_labels, all_predictions, average=None)
recalls = recall_score(all_labels, all_predictions, average=None)
f1_scores = f1_score(all_labels, all_predictions, average=None)

vgg16_precision = np.mean(precisions)
vgg16_recall = np.mean(recalls)
vgg16_f1_score = np.mean(f1_scores)
vgg16_acc = predict_accuracy

print("VGG-16's precision", vgg16_precision)
print("VGG-16's recall", vgg16_recall)
print("VGG-16's f1-score",vgg16_f1_score)
print(f"VGG-16's Accuracy: {vgg16_acc}")
# Out:
# VGG-16's precision 0.7756576690918117
# VGG-16's recall 0.7682125915959782
# VGG-16's f1-score 0.7639697139712853
# VGG-16's Accuracy: 0.7681218989460087

# %% [markdown]
# DenseNet121

# %%
densenet121 = models.densenet121(pretrained=True)

for param in densenet121.features.parameters():
    param.requires_grad = False

in_features = densenet121.classifier.in_features
num_classes = 14
densenet121.classifier = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

# %%
learning_rate = 0.0001
num_epochs = 100
weight_decay = 0.001

# %%
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(
        densenet121.classifier.parameters(), lr=learning_rate, weight_decay=weight_decay)

# %%
# Các giá trị cần lưu để đánh giá model
train_loss_list = []
train_accuracy_list = []
validate_loss_list = []  # Để lưu loss trên tập validate
validate_accuracy_list = []  # Để lưu accuracy trên tập validate

best_loss = float('inf')  # Giá trị loss tốt nhất
patience = 5  # Số epoch không giảm loss hoặc không tăng accuracy cho phép trước khi dừng
no_improvement_count = 0  # Đếm số epoch không cải thiện

# %%
densenet121.to(device)
for epoch in range(num_epochs):
    densenet121.train()
    total_train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = densenet121(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = correct_train / total_train
    average_train_loss = total_train_loss / len(train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(average_train_loss)

    # Validation
    densenet121.eval()
    total_validation_loss = 0.0
    correct_validation = 0
    total_validation = 0
    
    with torch.no_grad():
        for inputs, labels in validate_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = densenet121(inputs)
            loss = criterion(outputs, labels)
            
            total_validation_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
    
    validation_accuracy = correct_validation / total_validation
    average_validation_loss = total_validation_loss / len(validate_loader)
    validate_accuracy_list.append(validation_accuracy)
    validate_loss_list.append(average_validation_loss)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {average_train_loss:.4f}, Train Accuracy: {100 * train_accuracy:.2f}%, Validation Loss: {average_validation_loss:.4f}, Validation Accuracy: {100 * validation_accuracy:.2f}%')

    if validate_loss_list[-1] >= best_loss:
        no_improvement_count += 1
    else:
        best_loss = validate_loss_list[-1]
        no_improvement_count = 0
        # Nếu không cải thiện trong số lần đã định, dừng huấn luyện
    if no_improvement_count >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        break
# Out:
# Epoch 1/100, Train Loss: 2.2310, Train Accuracy: 26.99%, Validation Loss: 1.8993, Validation Accuracy: 39.76%
# Epoch 2/100, Train Loss: 1.8924, Train Accuracy: 38.15%, Validation Loss: 1.7242, Validation Accuracy: 44.44%
# Epoch 3/100, Train Loss: 1.7673, Train Accuracy: 42.00%, Validation Loss: 1.6389, Validation Accuracy: 46.99%
# Epoch 4/100, Train Loss: 1.6960, Train Accuracy: 44.06%, Validation Loss: 1.5818, Validation Accuracy: 48.48%
# Epoch 5/100, Train Loss: 1.6463, Train Accuracy: 45.64%, Validation Loss: 1.5390, Validation Accuracy: 49.43%
# Epoch 6/100, Train Loss: 1.6060, Train Accuracy: 46.85%, Validation Loss: 1.5043, Validation Accuracy: 50.58%
# Epoch 7/100, Train Loss: 1.5728, Train Accuracy: 47.76%, Validation Loss: 1.4775, Validation Accuracy: 51.29%
# Epoch 8/100, Train Loss: 1.5497, Train Accuracy: 48.39%, Validation Loss: 1.4554, Validation Accuracy: 51.91%
# Epoch 9/100, Train Loss: 1.5275, Train Accuracy: 49.20%, Validation Loss: 1.4361, Validation Accuracy: 52.48%
# Epoch 10/100, Train Loss: 1.5076, Train Accuracy: 49.80%, Validation Loss: 1.4171, Validation Accuracy: 52.94%
# Epoch 11/100, Train Loss: 1.4889, Train Accuracy: 50.40%, Validation Loss: 1.3989, Validation Accuracy: 53.52%
# Epoch 12/100, Train Loss: 1.4761, Train Accuracy: 50.76%, Validation Loss: 1.3869, Validation Accuracy: 53.86%
# Epoch 13/100, Train Loss: 1.4619, Train Accuracy: 51.24%, Validation Loss: 1.3739, Validation Accuracy: 54.27%
# Epoch 14/100, Train Loss: 1.4483, Train Accuracy: 51.53%, Validation Loss: 1.3630, Validation Accuracy: 54.78%
# Epoch 15/100, Train Loss: 1.4352, Train Accuracy: 51.92%, Validation Loss: 1.3504, Validation Accuracy: 54.95%
# Epoch 16/100, Train Loss: 1.4247, Train Accuracy: 52.32%, Validation Loss: 1.3415, Validation Accuracy: 55.35%
# Epoch 17/100, Train Loss: 1.4149, Train Accuracy: 52.47%, Validation Loss: 1.3288, Validation Accuracy: 55.78%
# Epoch 18/100, Train Loss: 1.4050, Train Accuracy: 52.82%, Validation Loss: 1.3215, Validation Accuracy: 56.00%
# Epoch 19/100, Train Loss: 1.3961, Train Accuracy: 53.12%, Validation Loss: 1.3108, Validation Accuracy: 56.19%
# Epoch 20/100, Train Loss: 1.3885, Train Accuracy: 53.39%, Validation Loss: 1.3047, Validation Accuracy: 56.54%
# Epoch 21/100, Train Loss: 1.3816, Train Accuracy: 53.62%, Validation Loss: 1.2970, Validation Accuracy: 56.62%
# Epoch 22/100, Train Loss: 1.3739, Train Accuracy: 53.73%, Validation Loss: 1.2898, Validation Accuracy: 56.91%
# Epoch 23/100, Train Loss: 1.3659, Train Accuracy: 54.03%, Validation Loss: 1.2841, Validation Accuracy: 57.29%
# Epoch 24/100, Train Loss: 1.3612, Train Accuracy: 54.20%, Validation Loss: 1.2786, Validation Accuracy: 57.37%
# Epoch 25/100, Train Loss: 1.3527, Train Accuracy: 54.43%, Validation Loss: 1.2683, Validation Accuracy: 57.50%
# Epoch 26/100, Train Loss: 1.3497, Train Accuracy: 54.60%, Validation Loss: 1.2633, Validation Accuracy: 57.70%
# Epoch 27/100, Train Loss: 1.3414, Train Accuracy: 54.75%, Validation Loss: 1.2573, Validation Accuracy: 58.06%
# Epoch 28/100, Train Loss: 1.3356, Train Accuracy: 54.80%, Validation Loss: 1.2535, Validation Accuracy: 58.19%
# Epoch 29/100, Train Loss: 1.3327, Train Accuracy: 55.16%, Validation Loss: 1.2491, Validation Accuracy: 58.22%
# Epoch 30/100, Train Loss: 1.3256, Train Accuracy: 55.33%, Validation Loss: 1.2418, Validation Accuracy: 58.64%
# Epoch 31/100, Train Loss: 1.3232, Train Accuracy: 55.17%, Validation Loss: 1.2411, Validation Accuracy: 58.72%
# Epoch 32/100, Train Loss: 1.3192, Train Accuracy: 55.42%, Validation Loss: 1.2343, Validation Accuracy: 58.71%
# Epoch 33/100, Train Loss: 1.3155, Train Accuracy: 55.47%, Validation Loss: 1.2280, Validation Accuracy: 59.01%
# Epoch 34/100, Train Loss: 1.3110, Train Accuracy: 55.56%, Validation Loss: 1.2248, Validation Accuracy: 59.10%
# Epoch 35/100, Train Loss: 1.3084, Train Accuracy: 55.77%, Validation Loss: 1.2216, Validation Accuracy: 59.16%
# Epoch 36/100, Train Loss: 1.3009, Train Accuracy: 56.08%, Validation Loss: 1.2174, Validation Accuracy: 59.37%
# Epoch 37/100, Train Loss: 1.2989, Train Accuracy: 55.93%, Validation Loss: 1.2132, Validation Accuracy: 59.62%
# Epoch 38/100, Train Loss: 1.2977, Train Accuracy: 56.14%, Validation Loss: 1.2077, Validation Accuracy: 59.62%
# Epoch 39/100, Train Loss: 1.2931, Train Accuracy: 56.22%, Validation Loss: 1.2078, Validation Accuracy: 59.75%
# Epoch 40/100, Train Loss: 1.2885, Train Accuracy: 56.35%, Validation Loss: 1.2056, Validation Accuracy: 59.75%
# Epoch 41/100, Train Loss: 1.2878, Train Accuracy: 56.39%, Validation Loss: 1.2002, Validation Accuracy: 59.83%
# Epoch 42/100, Train Loss: 1.2835, Train Accuracy: 56.56%, Validation Loss: 1.1976, Validation Accuracy: 60.09%
# Epoch 43/100, Train Loss: 1.2806, Train Accuracy: 56.57%, Validation Loss: 1.1959, Validation Accuracy: 59.99%
# Epoch 44/100, Train Loss: 1.2771, Train Accuracy: 56.83%, Validation Loss: 1.1940, Validation Accuracy: 60.15%
# Epoch 45/100, Train Loss: 1.2740, Train Accuracy: 56.82%, Validation Loss: 1.1912, Validation Accuracy: 60.13%
# Epoch 46/100, Train Loss: 1.2718, Train Accuracy: 56.81%, Validation Loss: 1.1873, Validation Accuracy: 60.09%
# Epoch 47/100, Train Loss: 1.2689, Train Accuracy: 56.80%, Validation Loss: 1.1845, Validation Accuracy: 60.32%
# Epoch 48/100, Train Loss: 1.2678, Train Accuracy: 56.99%, Validation Loss: 1.1821, Validation Accuracy: 60.51%
# Epoch 49/100, Train Loss: 1.2654, Train Accuracy: 56.93%, Validation Loss: 1.1811, Validation Accuracy: 60.38%
# Epoch 50/100, Train Loss: 1.2627, Train Accuracy: 57.10%, Validation Loss: 1.1769, Validation Accuracy: 60.58%
# Epoch 51/100, Train Loss: 1.2635, Train Accuracy: 57.05%, Validation Loss: 1.1746, Validation Accuracy: 60.68%
# Epoch 52/100, Train Loss: 1.2586, Train Accuracy: 57.21%, Validation Loss: 1.1742, Validation Accuracy: 60.61%
# Epoch 53/100, Train Loss: 1.2573, Train Accuracy: 57.28%, Validation Loss: 1.1707, Validation Accuracy: 60.68%
# Epoch 54/100, Train Loss: 1.2573, Train Accuracy: 57.26%, Validation Loss: 1.1702, Validation Accuracy: 60.75%
# Epoch 55/100, Train Loss: 1.2524, Train Accuracy: 57.41%, Validation Loss: 1.1658, Validation Accuracy: 60.90%
# Epoch 56/100, Train Loss: 1.2502, Train Accuracy: 57.48%, Validation Loss: 1.1656, Validation Accuracy: 60.77%
# Epoch 57/100, Train Loss: 1.2496, Train Accuracy: 57.41%, Validation Loss: 1.1630, Validation Accuracy: 60.97%
# Epoch 58/100, Train Loss: 1.2497, Train Accuracy: 57.59%, Validation Loss: 1.1616, Validation Accuracy: 61.12%
# Epoch 59/100, Train Loss: 1.2467, Train Accuracy: 57.45%, Validation Loss: 1.1607, Validation Accuracy: 61.09%
# Epoch 60/100, Train Loss: 1.2467, Train Accuracy: 57.49%, Validation Loss: 1.1595, Validation Accuracy: 61.03%
# Epoch 61/100, Train Loss: 1.2436, Train Accuracy: 57.83%, Validation Loss: 1.1558, Validation Accuracy: 61.20%
# Epoch 62/100, Train Loss: 1.2440, Train Accuracy: 57.86%, Validation Loss: 1.1559, Validation Accuracy: 61.07%
# Epoch 63/100, Train Loss: 1.2396, Train Accuracy: 57.89%, Validation Loss: 1.1546, Validation Accuracy: 61.15%
# Epoch 64/100, Train Loss: 1.2421, Train Accuracy: 57.59%, Validation Loss: 1.1530, Validation Accuracy: 61.41%
# Epoch 65/100, Train Loss: 1.2383, Train Accuracy: 57.82%, Validation Loss: 1.1512, Validation Accuracy: 61.40%
# Epoch 66/100, Train Loss: 1.2372, Train Accuracy: 57.94%, Validation Loss: 1.1490, Validation Accuracy: 61.39%
# Epoch 67/100, Train Loss: 1.2326, Train Accuracy: 58.00%, Validation Loss: 1.1490, Validation Accuracy: 61.56%
# Epoch 68/100, Train Loss: 1.2345, Train Accuracy: 57.94%, Validation Loss: 1.1491, Validation Accuracy: 61.62%
# Epoch 69/100, Train Loss: 1.2344, Train Accuracy: 57.93%, Validation Loss: 1.1461, Validation Accuracy: 61.54%
# Epoch 70/100, Train Loss: 1.2326, Train Accuracy: 57.85%, Validation Loss: 1.1443, Validation Accuracy: 61.69%
# Epoch 71/100, Train Loss: 1.2288, Train Accuracy: 58.07%, Validation Loss: 1.1438, Validation Accuracy: 61.64%
# Epoch 72/100, Train Loss: 1.2284, Train Accuracy: 58.16%, Validation Loss: 1.1432, Validation Accuracy: 61.85%
# Epoch 73/100, Train Loss: 1.2263, Train Accuracy: 58.28%, Validation Loss: 1.1422, Validation Accuracy: 61.74%
# Epoch 74/100, Train Loss: 1.2258, Train Accuracy: 58.37%, Validation Loss: 1.1397, Validation Accuracy: 61.71%
# Epoch 75/100, Train Loss: 1.2272, Train Accuracy: 58.20%, Validation Loss: 1.1390, Validation Accuracy: 61.78%
# Epoch 76/100, Train Loss: 1.2231, Train Accuracy: 58.34%, Validation Loss: 1.1393, Validation Accuracy: 61.88%
# Epoch 77/100, Train Loss: 1.2246, Train Accuracy: 58.12%, Validation Loss: 1.1352, Validation Accuracy: 61.85%
# Epoch 78/100, Train Loss: 1.2217, Train Accuracy: 58.29%, Validation Loss: 1.1358, Validation Accuracy: 61.77%
# Epoch 79/100, Train Loss: 1.2214, Train Accuracy: 58.35%, Validation Loss: 1.1347, Validation Accuracy: 61.91%
# Epoch 80/100, Train Loss: 1.2214, Train Accuracy: 58.21%, Validation Loss: 1.1348, Validation Accuracy: 61.82%
# Epoch 81/100, Train Loss: 1.2201, Train Accuracy: 58.43%, Validation Loss: 1.1317, Validation Accuracy: 61.88%
# Epoch 82/100, Train Loss: 1.2191, Train Accuracy: 58.42%, Validation Loss: 1.1327, Validation Accuracy: 61.94%
# Epoch 83/100, Train Loss: 1.2174, Train Accuracy: 58.35%, Validation Loss: 1.1327, Validation Accuracy: 61.97%
# Epoch 84/100, Train Loss: 1.2177, Train Accuracy: 58.49%, Validation Loss: 1.1334, Validation Accuracy: 61.96%
# Epoch 85/100, Train Loss: 1.2148, Train Accuracy: 58.62%, Validation Loss: 1.1300, Validation Accuracy: 62.17%
# Epoch 86/100, Train Loss: 1.2138, Train Accuracy: 58.57%, Validation Loss: 1.1283, Validation Accuracy: 62.19%
# Epoch 87/100, Train Loss: 1.2131, Train Accuracy: 58.64%, Validation Loss: 1.1284, Validation Accuracy: 62.10%
# Epoch 88/100, Train Loss: 1.2121, Train Accuracy: 58.64%, Validation Loss: 1.1269, Validation Accuracy: 62.16%
# Epoch 89/100, Train Loss: 1.2115, Train Accuracy: 58.70%, Validation Loss: 1.1260, Validation Accuracy: 62.11%
# Epoch 90/100, Train Loss: 1.2112, Train Accuracy: 58.60%, Validation Loss: 1.1225, Validation Accuracy: 62.19%
# Epoch 91/100, Train Loss: 1.2118, Train Accuracy: 58.68%, Validation Loss: 1.1248, Validation Accuracy: 62.11%
# Epoch 92/100, Train Loss: 1.2075, Train Accuracy: 58.72%, Validation Loss: 1.1217, Validation Accuracy: 62.17%
# Epoch 93/100, Train Loss: 1.2083, Train Accuracy: 58.84%, Validation Loss: 1.1216, Validation Accuracy: 62.48%
# Epoch 94/100, Train Loss: 1.2071, Train Accuracy: 58.68%, Validation Loss: 1.1220, Validation Accuracy: 62.33%
# Epoch 95/100, Train Loss: 1.2074, Train Accuracy: 58.68%, Validation Loss: 1.1221, Validation Accuracy: 62.48%
# Epoch 96/100, Train Loss: 1.2093, Train Accuracy: 58.82%, Validation Loss: 1.1218, Validation Accuracy: 62.48%
# Epoch 97/100, Train Loss: 1.2069, Train Accuracy: 58.75%, Validation Loss: 1.1183, Validation Accuracy: 62.45%
# Epoch 98/100, Train Loss: 1.2069, Train Accuracy: 58.71%, Validation Loss: 1.1186, Validation Accuracy: 62.45%
# Epoch 99/100, Train Loss: 1.2061, Train Accuracy: 58.74%, Validation Loss: 1.1188, Validation Accuracy: 62.23%
# Epoch 100/100, Train Loss: 1.2044, Train Accuracy: 58.84%, Validation Loss: 1.1165, Validation Accuracy: 62.26%

# %%
model_save_path = "GUI/models/app_classification_densenet121.pth"
torch.save({
    'model_state_dict': densenet121.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_list': train_loss_list,
    'validate_loss_list': validate_loss_list,
    'train_accuracy_list': train_accuracy_list,
    'validate_accuracy_list': validate_accuracy_list
}, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to GUI/models/app_classification_densenet121.pth

# %%
model_save_path = "GUI/models/app_classification_densenet121.pth"

densenet121 = models.densenet121(pretrained=True)

for param in densenet121.features.parameters():
    param.requires_grad = False

in_features = densenet121.classifier.in_features
num_classes = 14
densenet121.classifier = nn.Sequential(
    nn.Linear(in_features, 128),
    nn.ReLU(inplace=True),
    nn.Dropout(0.5),
    nn.Linear(128, num_classes),
    nn.LogSoftmax(dim=1)
)

checkpoint = torch.load(model_save_path)
densenet121.load_state_dict(checkpoint['model_state_dict'])

train_loss_list = checkpoint['train_loss_list']
validate_loss_list = checkpoint['validate_loss_list']
train_accuracy_list = checkpoint['train_accuracy_list']
validate_accuracy_list = checkpoint['validate_accuracy_list']

# %%
densenet121 = densenet121.to(device)
densenet121.eval()
correct_predictions = 0
total_predictions = 0
all_predictions = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
            
        outputs = densenet121(inputs)
            
        _, predicted = torch.max(outputs, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    
    predict_accuracy = correct_predictions / total_predictions
    
    print(predict_accuracy)
# Out:
# 0.6548545257038842

# %%
epochs = range(1, len(train_accuracy_list) + 1)
# Độ chính xác trên tập huấn luyện và tập validate
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_accuracy_list, 'b', label='Train Accuracy')
plt.plot(epochs, validate_accuracy_list, 'r', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss_list, 'b', label='Train Loss')
plt.plot(epochs, validate_loss_list, 'r', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Tính confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# In ra confusion matrix
class_names = [str(i) for i in range(len(cm))]
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="g",
            xticklabels=class_names, yticklabels=class_names)

for i in range(len(class_names)):
    plt.text(i + 0.5, i + 0.5, cm[i, i], ha="center",
             va="center", color="black")

print("DenseNet121's Confusion Matrix:")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# DenseNet121's Confusion Matrix:

# %%
# Tính Precision, Recall, và F1-Score cho từng lớp
precisions = precision_score(all_labels, all_predictions, average=None)
recalls = recall_score(all_labels, all_predictions, average=None)
f1_scores = f1_score(all_labels, all_predictions, average=None)

densenet121_precision = np.mean(precisions)
densenet121_recall = np.mean(recalls)
densenet121_f1_score = np.mean(f1_scores)
densenet121_acc = predict_accuracy

print("DenseNet121's precision", densenet121_precision)
print("DenseNet121's recall", densenet121_recall)
print("DenseNet121's f1-score",densenet121_f1_score)
print(f"DenseNet121's Accuracy: {densenet121_acc}")
# Out:
# DenseNet121's precision 0.6540174077170567
# DenseNet121's recall 0.655184946750998
# DenseNet121's f1-score 0.6511528790568423
# DenseNet121's Accuracy: 0.6548545257038842
